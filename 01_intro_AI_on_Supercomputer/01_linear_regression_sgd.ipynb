# %% [markdown]
# # Artificial intelligence in a nutshell
#
# In this notebook, we will talk about
# * What is AI training?
# * How does large language model work?
# * A simple AI model: linear regression
#
# **How to run this notebook on Polaris**
# * Go to https://jupyter.alcf.anl.gov, and click "Login Polaris"
# * After login, select ```ALCFAITP``` project and ```ALCFAITP``` queue during the lecture (use ```debug``` queue outside of the lecture)
# * Load the notebook and select "datascience/conda-2023-01-10" python kernel
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/jupyter1.png?raw=1" width="600" />
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/jupyter2.png?raw=1" width="600" />
# </p>
#
# **How to run this notebook on Google Colab**
#
# * Go to https://colab.research.google.com/, sign in or sign up
# * "File"-> "open notebook"
# * choose ```01_intro_AI_on_Supercomputer/01_linear_regression_sgd.ipynb``` from the list
# ![Google Colab](https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/colab.png?raw=1)
#
# ## What is AI training?
# **Two ways of learning English**
# * through learning rules;
# * through hearing a lot of speakings
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/data_driven.png?raw=1" width="1000" />
# </p>
#
# I learned English in my middle school, and memorized a lot of grammar rules in my mind. Every time when I speak, I try to follow the grammar rules as much as I can. But I always break the rules.
#
# However, my daugher learned English differently. She learns speaking by hearing a lot of speaking from TV, teachers, classmates, and her older brother. The fact is that, she seldomly breaks grammar rules. This way of learning by observing patterns is very powerful! This is the essence of AI or data driven science.
#
# ## How does large language model work?
#
# Large Language Models, like GPT, function by pre-training on extensive datasets to learn language patterns, utilizing transformer architecture for contextual understanding, and can be fine-tuned for specific tasks, enabling them to generate coherent and contextually relevant text based on provided inputs.
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/llm2.png?raw=1" width="600" />
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/chatgpt_response.png?raw=1" width="160" />
# </p>
#
# **More complicated example**
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/chatgpt_poem.png?raw=1" width="400" />
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/martin.png?raw=1" width="450" />
# </p>
#
# You can do this on https://chat.openai.com
#
# ## Simplest AI model example: linear regression
# This example is adopted from Bethany Lusch, ALCF.
#
# Linear regression is the simplest example ``learning" from existing data for future prediction.
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/excel_linear_regression.jpg?raw=1" width="400" />
# </p>
#
# We're going to review the math involved in this process to help understand how training an AI works.
#
# First we will load some tools that others wrote and we can use to help us work.
# * [Pandas](https://pandas.pydata.org/docs/): a toolkit for working with row vs. column data, like excel sheets, and CSV (Comma Seperated Values) files.
# * [Numpy](https://numpy.org/doc/): a toolkit for managing arrays, vectors, matrices, etc, doing math with them, slicing them up, and many other handy things.
# * [Matplotlib](https://matplotlib.org/stable/index.html): a toolkit for plotting data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipydis
import time

# %% [markdown]
# ### Dataset
# We used a realestate dataset from Kaggle to produce this reduced dataset. This dataset contains the _sale price_ and _above ground square feet_ of many houses. We can use this data for our linear regression.
#
# We use Pandas to read the data file which is stored as Comma Separated Values (CSV). and print the column labels. CSV files are similar to excel sheets.

# %%
! [ -e ./slimmed_realestate_data.csv ] || wget https://raw.githubusercontent.com/argonne-lcf/ai-science-training-series/main/01_intro_AI_on_Supercomputer/slimmed_realestate_data.csv
data = pd.read_csv('slimmed_realestate_data.csv')
print(data.columns)
# Out:
# --2024-10-08 16:32:07--  https://raw.githubusercontent.com/argonne-lcf/ai-science-training-series/main/01_intro_AI_on_Supercomputer/slimmed_realestate_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8804 (8.6K) [text/plain]
# Saving to: ‘slimmed_realestate_data.csv’
#
# slimmed_realestate_ 100%[===================>]   8.60K  --.-KB/s    in 0s
#
# 2024-10-08 16:32:07 (17.2 MB/s) - ‘slimmed_realestate_data.csv’ saved [8804/8804]
#
# Index(['Unnamed: 0', 'SalePrice', 'GrLivArea'], dtype='object')

# %% [markdown]
# Now pandas provides some helpful tools for us to inspect our data. It provides a `plot()` function that, behind the scenes, is calling into the _Matplotlib_ library and calling the function [matplotlib.pyplot.plot()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html). In this case, we simply tell it the names of the columns we want as our _x_ and _y_ values and the `style` (`'.'` tells `matplotlib` to use a small dot to represent each data point).

# %%
data.plot(x='GrLivArea', y='SalePrice',style='.')
# Out:
# <Axes: xlabel='GrLivArea'>

# %% [markdown]
# ### Theory of linear regression
#
# The goal of learning regression is to find a line that is closest to all the points.
#
# The slope and intercept of such a line $y = m x + b$ can be found as:
#
# $$m = { n (\Sigma xy) - (\Sigma x) (\Sigma y) \over n (\Sigma x^2) - (\Sigma x)^2 } $$
#
# $$b = { (\Sigma y) (\Sigma x^2) - (\Sigma x) (\Sigma xy) \over n (\Sigma x^2) - (\Sigma x)^2 } $$
#
# Details derivation of this can be found [here](https://en.wikipedia.org/wiki/Simple_linear_regression).
#
# We'll break this calculation into a few steps to help make it easier.
#
# First lets define $x$ and $y$. $x$ will be our _above ground square footage_ and $y$ will be _sale price_. In our equations we have a few different values we need, such as $n$ which is just the number of points we have:

# %%
n = len(data)

# %% [markdown]
# Then we need our $x$ and $y$ by selecting only the column we care about for each one. Note about data formats: `data` is a Pandas [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame) object which has rows and columns; `data['GrLivArea']` is a Pandas [Series](https://pandas.pydata.org/docs/reference/api/pandas.Series.html) object which only has rows; then we also convert from _Pandas_ data formats (in this case a _Series_) to _Numpy_ data formats using the `to_numpy()` function which is part of the Pandas _Series_ object.

# %%
x = data['GrLivArea'].to_numpy()
y = data['SalePrice'].to_numpy()

# %% [markdown]
# Now we will calculate $\Sigma xy$, $\Sigma x$, $\Sigma y$, and $\Sigma x^2$:

# %%
sum_xy = np.sum(x*y)
sum_x = np.sum(x)
sum_y = np.sum(y)
sum_x2 = np.sum(x*x)

# %% [markdown]
# The denominator in the equation for $m$ and $b$ are the same so we can calculate that once:

# %%
denominator = n * sum_x2 - sum_x * sum_x

# %% [markdown]
# Then we can calculate our fit values:

# %%
m = (n * sum_xy - sum_x * sum_y) / denominator
b = (sum_y * sum_x2 - sum_x * sum_xy) / denominator
print('y = %f * x + %f' % (m,b))

# saving these for later comparison
m_calc = m
b_calc = b
# Out:
# y = 87.688145 * x + 34754.077892

# %% [markdown]
# Now we can plot the fit results with our data to see how we did.
#
# First we define a plotting function because we're going to do this often and we want to reuse our code:

# %%
def plot_data(x,y,m,b,plt = plt):
   # plot our data points with 'bo' = blue circles
   plt.plot(x,y,'bo')
   # create the line based on our linear fit
   # first we need to make x points
   # the 'arange' function generates points between two limits (min,max)
   linear_x = np.arange(x.min(),x.max())
   # now we use our fit parameters to calculate the y points based on our x points
   linear_y = linear_x * m + b
   # plot the linear points using 'r-' = red line
   plt.plot(linear_x,linear_y,'r-',label='fit')

# %% [markdown]
# Now can use this function to plot our results:

# %%
plot_data(x,y,m,b)

# %% [markdown]
# ### Training through Stochastic Gradient Descent (SGD)
#
# SGD is a common method in AI for training deep neural networks on large datasets. It is an iterative method for optimizing a loss function that we get to define. We will use this simple linear regression to demonstrate how it works.
#
# #### The model
#
# In AI, neural networks are often referred to as a _model_ because, once fully trained, they should model (AKA predict) the behavior of our system. In our example, the system is how house prices vary based on house size. We know our system is roughly driven by a linear function:
#
# $$ \hat{y_i}(x_i) = m * x_i + b $$
#
# We just need to figure out $m$ and $b$. Let's create a function that calculates our model given $x$, $m$, and $b$.

# %%
def model(x,m,b):
   return m * x + b

# %% [markdown]
# #### The Loss Function
#
# A _loss function_, or _objective function_, is something we define and is based on what we want to achieve. In the method of SGD, it is our goal to minimize (or make close to zero) the values calculated from the _loss function_. In our example, we ideally want the prediction of our _model_ to be equal to the actual data, though we will settle for "as close as possible".
#
# So we will select our _loss function_ to be the [Mean Squared Error](https://en.wikipedia.org/wiki/Mean_squared_error) function:
#
# $$ L(y_i,\hat{y_i}) = (y_i - \hat{y_i}(x_i))^2 $$
#
# where $y_i$ is our $i^{th}$ entry in the `data['SalePrice']` vector and $\hat{y_i}$ is the prediction based on evaluting $m * x_i + b$.
#
# This function looks like the figure below when we plot it with $x=y_i - \hat{y_i}(x_i)$ and we we want to be down near $y_i - \hat{y_i}(x_i) = 0$ which indicates that our $y_i$ is as close as possible to $\hat{y_i}$.
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/loss_func.png?raw=1" width="400" />
# </p>
#
# Here we crate a function that calculates this for us.

# %%
def loss(x,y,m,b):
   y_predicted = model(x,m,b)
   return np.power( y - y_predicted, 2 )

# %% [markdown]
# #### Minimizing the Loss Function
#
# We want to use the loss function in order to guide how to update $m$ and $b$ to better model our system. In calculus we learn to minimize a function with respect to a variable you calculate the _partial derivative_ with respect to the variable you want to vary.
#
# $$ { \partial L \over \partial m } = 0 $$
#
# The location of the solution to this is the minimum as shown in the figure above. We can write down the partial derivative of the loss function as:
#
# $$ { \partial L \over \partial m } = -2 x_i (y_i - \hat{y_i}(x_i)) $$
# $$ { \partial L \over \partial b } = -2 (y_i - \hat{y_i}(x_i)) $$
#
# We can use this to calculate an adjustment to $m$ and $b$ that will reduce the loss function, effectively improving our fitting parameters. This is done using this equation:
#
# $$ m' = m - \eta { \partial L \over \partial m }$$
# $$ b' = b - \eta { \partial L \over \partial b }$$
#
# Here our original $m$ and $b$ are adjusted by the partial derivative multiplied by some small factor, $\eta$, called the _learning rate_. This learning rate is very important in our process and must be tuned for every problem.
#
# In our example, the selection of the learning rate essentially defines how close we can get to the minimum, AKA the best fit solution. This figure shows what happens when we pick a large learning rate. We first select a starting point in our loss function (typically randomly), then every update from $m$/$b$ to $m'$/$b'$ results in a shift to somewhere else on our loss function (following the red arrows). In this example, our learning rate ($\eta$) has been selected too large such that we bounce back and forth around the minimum, never reaching it.
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/parabola_largeLR.png?raw=1" width="400" />
# </p>
#
# If we select a smaller learning we can see better behavior in the next figure.
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/parabola_smallLR.png?raw=1" width="400" />
# </p>
#
# Though, keep in mind, too small a learning rate results is so little progress toward the minimum that you may never reach it!
#
# A pit fall of SGD that one must be aware of is when your loss function is complex, with many minima. The next figure shows such a case, in which we select a small learning rate and our starting point happens to be near a local minimum that is not the lowest minimum. As shown, we do reach a minimum, but it isn't the lowest minimum in our loss function. It could be that we randomly select a starting point near the minimum we care about, but we should build methods that are more robust against randomly getting the right answer.
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/local_min_smallLR.png?raw=1" width="400" />
# </p>
#
# Then, if we increase our learning rate too much, we bounce around again.
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/local_min_largeLR.png?raw=1" width="400" />
# </p>
#
# What we want to do in this situation is start with a large learning rate and slowly reduce its size as we progress. That is shown in this next figure.
#
# <p float="center">
#   <img src="https://github.com/jessdagostini/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/local_min_variableLR.png?raw=1" width="400" />
# </p>
#
# As you can see, this process is not perfect and could still land in a local minimum, but it is important to be aware of these behaviors as you utilize SGD in machine learning.
#
# So let's continue, we'll build functions we can use to update our fit parameters, $m$ and $b$.

# %%
def updated_m(x,y,m,b,learning_rate):
   dL_dm = - 2 * x * (y - model(x,m,b))
   dL_dm = np.mean(dL_dm)
   return m - learning_rate * dL_dm

def updated_b(x,y,m,b,learning_rate):
   dL_db = - 2 * (y - model(x,m,b))
   dL_db = np.mean(dL_db)
   return b - learning_rate * dL_db

# %% [markdown]
# # Putting it together
#
# We can now randomly select our initial slope and intercept:

# %%
m = 5.
b = 1000.
print('y_i = %.2f * x + %.2f' % (m,b))
# Out:
# y_i = 5.00 * x + 1000.00

# %% [markdown]
# Then we can calculate our Loss function:

# %%
l = loss(x,y,m,b)
print('first 10 loss values: ',l[:10])
# Out:
# first 10 loss values:  [3.03421561e+10 3.55511025e+10 1.24579082e+10 1.91656336e+10
#  1.60604929e+10 2.04432804e+10 1.72410030e+10 1.76517796e+10
#  1.52769600e+10 2.18152900e+10]

# %%
learning_rate = 1e-9
m = updated_m(x,y,m,b,learning_rate)
b = updated_b(x,y,m,b,learning_rate)
print('y_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f' % (m,b,m_calc,b_calc))
plot_data(x,y,m,b)
# Out:
# y_i = 5.47 * x + 1000.00     previously calculated: y_i = 87.69 * x + 34754.08

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []
# convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
data_x = data['GrLivArea'].to_numpy()
data_y = data['SalePrice'].to_numpy()
# we run our loop N times
loop_N = 30
for i in range(loop_N):
   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))

   # close/delete previous plots
   plt.close('all')

   # create a 1 by 2 plot grid
   fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
   # lot our usual output
   plot_data(data_x,data_y,m,b,ax[0])

   # here we also plot the calculated linear fit for comparison
   line_x = np.arange(data_x.min(),data_x.max())
   line_y = line_x * m_calc + b_calc
   ax[0].plot(line_x,line_y,'b-',label='calculated')
   # add a legend to the plot and x/y labels
   ax[0].legend()
   ax[0].set_xlabel('square footage')
   ax[0].set_ylabel('sale price')

   # plot the loss
   loss_x = np.arange(0,len(loss_history))
   loss_y = np.asarray(loss_history)
   ax[1].plot(loss_x,loss_y, 'o-')
   ax[1].set_yscale('log')
   ax[1].set_xlabel('loop step')
   ax[1].set_ylabel('loss')
   plt.show()
   # gives us time to see the plot
   time.sleep(2.5)
   # clears the plot when the next plot is ready to show.
   ipydis.clear_output(wait=True)
# Out:
# [029]  dy_i = 88.89 * x + 32912.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1478200827.641291

# %% [markdown]
# # Homework
# ## Mini Batch Training
# In AI, datasets are often very large and cannot be processed all at once as is done in the loop above. The data is instead randomly sampled in smaller _batches_ where each _batch_ contains `batch_size` inputs. How can you change the loop above to sample the dataset in smaller batches? Hint: Our `data` variable is a Pandas `DataFrame` object, search for "how to sample a DataFrame".
#
# Instead of using the entire dataset like
# ```python
# data_x = data['GrLivArea'].to_numpy()
# data_y = data['SalePrice'].to_numpy()
# ```
# Use
# ```python
# data_batch = data.sample(batch_size)
# data_x = data_batch['GrLivArea'].to_numpy()
# data_y = data_batch['SalePrice'].to_numpy()
# ```
#
# You also have to adjust the loop_N accordingly to make sure that it loop over the entire datasets the same number of times.
# ```python
# loop_N = 30*len(data)//batch_size
# ```
#
# Please plot your learning curve for different batch size, such as 32, 64, 128, 256, 512.
#
# ## Learning rate issue (Bonus)
# As described above, if the learning rate is too large, it will affect the convergence. Do your training with (batch_size = 64, learning_rate_m = 1e-7, learning_rate_b = 1e-1). Then linearly increase the batch size and learning rate until you see the training does not converge.
# ```
# (64, 1e-7, 1e-1)*1
# (64, 1e-7, 1e-1)*2
# (64, 1e-7, 1e-1)*4
# (64, 1e-7, 1e-1)*8
# ...
# ```
#
# **How to submit your homework**
# * Fork the github repo to your personal github
# * Make change to the 01_linear_regression_sgd.ipynb, and then push to your personal github
# * Provide the link of 01_linear_regression_sgd in the personal github.
#
# Follow the below instruction on how to do this:
# https://github.com/argonne-lcf/ai-science-training-series/blob/main/00_introToAlcf/03_githubHomework.md

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []
#define a batch size
batch_size = 32
# we run our loop N times
loop_N = 30*len(data)//batch_size
for i in range(loop_N):
   # We just want a sample of the dataset with batch_size size
   data_batch = data.sample(batch_size)
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()

   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d/%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,loop_N,m,b,m_calc,b_calc,loss_value))

# close/delete previous plots
plt.close('all')

# create a 1 by 2 plot grid
fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
# lot our usual output
plot_data(data_x,data_y,m,b,ax[0])

# here we also plot the calculated linear fit for comparison
line_x = np.arange(data_x.min(),data_x.max())
line_y = line_x * m_calc + b_calc
ax[0].plot(line_x,line_y,'b-',label='calculated')
# add a legend to the plot and x/y labels
ax[0].legend()
ax[0].set_xlabel('square footage')
ax[0].set_ylabel('sale price')

# plot the loss
loss_x = np.arange(0,len(loss_history))
loss_y = np.asarray(loss_history)
ax[1].plot(loss_x,loss_y, 'o-')
ax[1].set_yscale('log')
ax[1].set_xlabel('loop step')
ax[1].set_ylabel('loss')
plt.show()
# gives us time to see the plot
time.sleep(2.5)
# clears the plot when the next plot is ready to show.
ipydis.clear_output(wait=True)
# Out:
# [000/516]  dy_i = 75.34 * x + 13586.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3568497638.154304
# [001/516]  dy_i = 85.08 * x + 17704.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1131457082.736852
# [002/516]  dy_i = 92.00 * x + 19285.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1239217540.577738
# [003/516]  dy_i = 93.48 * x + 20396.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 558571980.521798
# [004/516]  dy_i = 94.10 * x + 21343.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1357370886.052469
# [005/516]  dy_i = 92.95 * x + 21253.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1079961930.101754
# [006/516]  dy_i = 89.49 * x + 21866.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1427794086.599918
# [007/516]  dy_i = 92.10 * x + 23647.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1067103179.549446
# [008/516]  dy_i = 94.19 * x + 25345.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1078011082.095519
# [009/516]  dy_i = 94.04 * x + 25675.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 595725082.209081
# [010/516]  dy_i = 91.03 * x + 25853.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1613491533.307621
# [011/516]  dy_i = 94.56 * x + 27674.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 920162152.495941
# [012/516]  dy_i = 92.07 * x + 27940.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1780044371.448261
# [013/516]  dy_i = 94.19 * x + 28663.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1510813900.436478
# [014/516]  dy_i = 94.32 * x + 28349.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 818070075.105973
# [015/516]  dy_i = 92.96 * x + 28059.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 682801256.479732
# [016/516]  dy_i = 91.16 * x + 27386.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 539932232.476083
# [017/516]  dy_i = 88.85 * x + 26776.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2031433062.538315
# [018/516]  dy_i = 89.80 * x + 28230.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 876114037.519151
# [019/516]  dy_i = 87.68 * x + 27860.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1584768515.530983
# [020/516]  dy_i = 88.74 * x + 28921.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 807138242.226615
# [021/516]  dy_i = 98.17 * x + 28691.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4013702010.542438
# [022/516]  dy_i = 96.26 * x + 28081.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1946723701.013670
# [023/516]  dy_i = 95.96 * x + 27995.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 783792885.694271
# [024/516]  dy_i = 92.59 * x + 27871.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640834740.793657
# [025/516]  dy_i = 91.24 * x + 27762.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1044111870.958304
# [026/516]  dy_i = 90.37 * x + 27095.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 777496682.707153
# [027/516]  dy_i = 89.43 * x + 27186.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1978055526.085448
# [028/516]  dy_i = 93.10 * x + 27302.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1196275771.190883
# [029/516]  dy_i = 93.30 * x + 27537.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 727390449.045590
# [030/516]  dy_i = 90.09 * x + 26947.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 652362444.545188
# [031/516]  dy_i = 88.95 * x + 28191.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1242930021.219365
# [032/516]  dy_i = 94.17 * x + 30508.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1112599024.891462
# [033/516]  dy_i = 86.63 * x + 29004.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 431347127.779714
# [034/516]  dy_i = 91.99 * x + 31023.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1424552860.846744
# [035/516]  dy_i = 93.08 * x + 31694.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 824467326.869974
# [036/516]  dy_i = 89.34 * x + 30085.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1097127582.065625
# [037/516]  dy_i = 88.12 * x + 30354.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1641688431.845770
# [038/516]  dy_i = 89.33 * x + 31466.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1234555640.040693
# [039/516]  dy_i = 90.43 * x + 31900.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 692418173.405776
# [040/516]  dy_i = 89.00 * x + 31256.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1863977178.605378
# [041/516]  dy_i = 87.84 * x + 31789.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1146308823.338625
# [042/516]  dy_i = 91.10 * x + 32519.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2528558478.617974
# [043/516]  dy_i = 90.01 * x + 32783.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 506116891.279546
# [044/516]  dy_i = 89.35 * x + 32313.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 844329156.812807
# [045/516]  dy_i = 88.68 * x + 32148.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1539797888.424280
# [046/516]  dy_i = 84.10 * x + 30916.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 905247454.172567
# [047/516]  dy_i = 86.33 * x + 31807.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 778738968.521361
# [048/516]  dy_i = 86.97 * x + 32765.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 986191774.171980
# [049/516]  dy_i = 85.40 * x + 32536.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1013497257.472821
# [050/516]  dy_i = 86.80 * x + 34021.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1150007015.162491
# [051/516]  dy_i = 86.59 * x + 34028.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 911090727.004894
# [052/516]  dy_i = 90.34 * x + 35556.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2275628022.611320
# [053/516]  dy_i = 85.55 * x + 34430.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626825901.952700
# [054/516]  dy_i = 82.11 * x + 34200.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1217727970.229894
# [055/516]  dy_i = 85.83 * x + 35767.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1390077049.397098
# [056/516]  dy_i = 81.33 * x + 34803.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1337228750.692845
# [057/516]  dy_i = 85.44 * x + 35760.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 971566760.029684
# [058/516]  dy_i = 80.70 * x + 34810.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1420828928.051726
# [059/516]  dy_i = 89.80 * x + 37442.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1796553369.621340
# [060/516]  dy_i = 89.09 * x + 37337.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 458557375.294097
# [061/516]  dy_i = 89.92 * x + 36620.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1409931443.378744
# [062/516]  dy_i = 90.27 * x + 36353.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 790699509.289697
# [063/516]  dy_i = 85.66 * x + 35067.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 943394916.281106
# [064/516]  dy_i = 86.65 * x + 35503.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1834072485.008255
# [065/516]  dy_i = 85.27 * x + 35328.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 699430260.520427
# [066/516]  dy_i = 87.19 * x + 35473.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1001647467.216634
# [067/516]  dy_i = 88.23 * x + 36239.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 990644216.144545
# [068/516]  dy_i = 97.05 * x + 35892.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3558052992.560936
# [069/516]  dy_i = 93.83 * x + 34961.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2080197655.426910
# [070/516]  dy_i = 91.32 * x + 34005.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 944499182.986037
# [071/516]  dy_i = 92.72 * x + 34364.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2663018895.810428
# [072/516]  dy_i = 93.12 * x + 35143.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1783116136.549332
# [073/516]  dy_i = 93.79 * x + 35280.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1974508704.972207
# [074/516]  dy_i = 92.63 * x + 34159.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1162001737.428723
# [075/516]  dy_i = 103.42 * x + 33543.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3587480305.977479
# [076/516]  dy_i = 96.06 * x + 30851.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1664543425.403764
# [077/516]  dy_i = 92.59 * x + 29304.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1170910404.334883
# [078/516]  dy_i = 91.86 * x + 29204.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1142131673.429743
# [079/516]  dy_i = 91.05 * x + 28761.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1842144350.535331
# [080/516]  dy_i = 89.40 * x + 28526.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1394957877.129478
# [081/516]  dy_i = 90.34 * x + 29721.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1176397466.373965
# [082/516]  dy_i = 90.33 * x + 30385.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 614617796.131134
# [083/516]  dy_i = 88.77 * x + 30059.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 723579183.377175
# [084/516]  dy_i = 93.59 * x + 31724.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1251995611.775398
# [085/516]  dy_i = 90.72 * x + 30975.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 787811991.944837
# [086/516]  dy_i = 90.62 * x + 31288.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1288945871.627230
# [087/516]  dy_i = 87.53 * x + 30942.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 788151653.331702
# [088/516]  dy_i = 86.46 * x + 31590.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1333198405.338452
# [089/516]  dy_i = 84.65 * x + 32412.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3262012327.740461
# [090/516]  dy_i = 90.82 * x + 34535.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2609516346.756379
# [091/516]  dy_i = 83.42 * x + 32274.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1054910621.235449
# [092/516]  dy_i = 86.74 * x + 34199.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2505036191.851723
# [093/516]  dy_i = 88.75 * x + 34593.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1192941172.232395
# [094/516]  dy_i = 88.26 * x + 34163.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 697373779.089179
# [095/516]  dy_i = 85.59 * x + 33412.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 877513213.616215
# [096/516]  dy_i = 86.77 * x + 34450.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1421520342.184923
# [097/516]  dy_i = 86.47 * x + 34450.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 686024896.812481
# [098/516]  dy_i = 92.15 * x + 34970.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1415061158.041324
# [099/516]  dy_i = 94.53 * x + 35892.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2205496283.437661
# [100/516]  dy_i = 89.38 * x + 33929.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1043996021.250534
# [101/516]  dy_i = 88.23 * x + 33868.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1156801992.938621
# [102/516]  dy_i = 87.46 * x + 34102.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 994134647.816432
# [103/516]  dy_i = 88.07 * x + 34470.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 838326753.846640
# [104/516]  dy_i = 89.12 * x + 34710.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1086878609.405692
# [105/516]  dy_i = 89.14 * x + 33832.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1426326227.869017
# [106/516]  dy_i = 89.63 * x + 34095.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1137524955.581580
# [107/516]  dy_i = 90.35 * x + 34759.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2733742434.441391
# [108/516]  dy_i = 86.31 * x + 34351.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1808916949.750921
# [109/516]  dy_i = 88.23 * x + 35001.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1114707189.192299
# [110/516]  dy_i = 88.17 * x + 35138.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 823133249.836749
# [111/516]  dy_i = 89.37 * x + 35110.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1206438812.967403
# [112/516]  dy_i = 88.48 * x + 34928.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1050339385.479592
# [113/516]  dy_i = 85.60 * x + 34457.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 818538599.515470
# [114/516]  dy_i = 84.59 * x + 34269.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1038649959.562917
# [115/516]  dy_i = 89.46 * x + 35410.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1461978854.147588
# [116/516]  dy_i = 88.01 * x + 35029.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 686191237.499796
# [117/516]  dy_i = 90.43 * x + 35700.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 955229145.670981
# [118/516]  dy_i = 89.66 * x + 35679.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 963169950.976494
# [119/516]  dy_i = 91.68 * x + 36258.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1134701260.357152
# [120/516]  dy_i = 86.13 * x + 34637.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1154194004.637968
# [121/516]  dy_i = 86.59 * x + 34906.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 876147697.348537
# [122/516]  dy_i = 86.37 * x + 34973.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1006419943.545530
# [123/516]  dy_i = 83.61 * x + 34671.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1813397747.277767
# [124/516]  dy_i = 87.05 * x + 35395.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1840984733.093733
# [125/516]  dy_i = 84.77 * x + 34815.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 726217512.432524
# [126/516]  dy_i = 87.09 * x + 36315.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1829432893.298432
# [127/516]  dy_i = 92.43 * x + 36921.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1572372983.075403
# [128/516]  dy_i = 91.41 * x + 36672.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 950996543.224977
# [129/516]  dy_i = 88.24 * x + 36283.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1876806865.052042
# [130/516]  dy_i = 89.21 * x + 36901.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 793175369.394372
# [131/516]  dy_i = 84.16 * x + 35877.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1185367794.941202
# [132/516]  dy_i = 89.24 * x + 36988.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1633233516.900979
# [133/516]  dy_i = 90.87 * x + 37275.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 854394786.202079
# [134/516]  dy_i = 89.81 * x + 36589.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1816524387.645789
# [135/516]  dy_i = 95.79 * x + 34897.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3942350507.649693
# [136/516]  dy_i = 90.88 * x + 33795.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 876124583.244788
# [137/516]  dy_i = 92.24 * x + 33997.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 704541514.664729
# [138/516]  dy_i = 93.55 * x + 34760.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 429020355.738640
# [139/516]  dy_i = 90.69 * x + 34458.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1650219650.672713
# [140/516]  dy_i = 89.37 * x + 34116.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 774852022.332052
# [141/516]  dy_i = 86.50 * x + 34103.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1191826801.320274
# [142/516]  dy_i = 97.33 * x + 34344.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3899093806.547152
# [143/516]  dy_i = 94.02 * x + 32616.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1019142274.086852
# [144/516]  dy_i = 89.36 * x + 31908.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 606187446.788311
# [145/516]  dy_i = 90.20 * x + 32409.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 557836359.378714
# [146/516]  dy_i = 88.50 * x + 31790.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1111565156.051064
# [147/516]  dy_i = 92.37 * x + 32851.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1069418529.404755
# [148/516]  dy_i = 88.27 * x + 32211.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2213880141.491199
# [149/516]  dy_i = 92.17 * x + 33490.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1687770122.509267
# [150/516]  dy_i = 86.70 * x + 32404.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1671822587.018922
# [151/516]  dy_i = 85.29 * x + 32201.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1787505512.990889
# [152/516]  dy_i = 85.85 * x + 32880.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1183748802.543244
# [153/516]  dy_i = 89.20 * x + 34071.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1041079180.616430
# [154/516]  dy_i = 93.80 * x + 34427.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 949824485.042710
# [155/516]  dy_i = 91.33 * x + 34103.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1852198214.730324
# [156/516]  dy_i = 86.06 * x + 33192.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 781195148.161120
# [157/516]  dy_i = 83.19 * x + 32789.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403782740.138573
# [158/516]  dy_i = 83.04 * x + 33308.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1100207434.938190
# [159/516]  dy_i = 84.07 * x + 33850.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1584062614.770144
# [160/516]  dy_i = 83.06 * x + 34610.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1454282369.413914
# [161/516]  dy_i = 83.83 * x + 35395.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 850615995.320352
# [162/516]  dy_i = 81.69 * x + 34738.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 800251822.224406
# [163/516]  dy_i = 83.24 * x + 34423.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2854498423.182458
# [164/516]  dy_i = 83.63 * x + 35221.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 972832410.876987
# [165/516]  dy_i = 82.49 * x + 35100.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 583394572.254035
# [166/516]  dy_i = 85.97 * x + 36041.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1066128552.392568
# [167/516]  dy_i = 87.02 * x + 36301.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 810736028.551878
# [168/516]  dy_i = 87.44 * x + 36112.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 886616788.200239
# [169/516]  dy_i = 86.91 * x + 36125.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1333050241.970366
# [170/516]  dy_i = 87.04 * x + 36549.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1231414054.434058
# [171/516]  dy_i = 88.18 * x + 36879.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2625247718.456259
# [172/516]  dy_i = 81.12 * x + 35597.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2746136557.192443
# [173/516]  dy_i = 83.41 * x + 36836.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 726278508.752905
# [174/516]  dy_i = 91.10 * x + 35679.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4949808544.554140
# [175/516]  dy_i = 93.87 * x + 35532.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1222903095.863770
# [176/516]  dy_i = 95.28 * x + 35971.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2896387525.516199
# [177/516]  dy_i = 91.94 * x + 34687.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1373571109.538406
# [178/516]  dy_i = 91.09 * x + 34614.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1571041236.717937
# [179/516]  dy_i = 91.04 * x + 34615.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 844750225.429604
# [180/516]  dy_i = 91.52 * x + 34075.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 795302044.518327
# [181/516]  dy_i = 91.38 * x + 34123.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1250025984.616337
# [182/516]  dy_i = 88.37 * x + 34149.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1906764736.245543
# [183/516]  dy_i = 86.94 * x + 34573.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1479318536.946904
# [184/516]  dy_i = 89.36 * x + 34956.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1267439591.196090
# [185/516]  dy_i = 88.04 * x + 34386.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 868672466.459252
# [186/516]  dy_i = 84.72 * x + 33606.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1322180083.867203
# [187/516]  dy_i = 96.93 * x + 33656.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4553560132.188271
# [188/516]  dy_i = 90.14 * x + 31483.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1864944278.209182
# [189/516]  dy_i = 91.25 * x + 31972.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1308139817.565425
# [190/516]  dy_i = 86.88 * x + 30910.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1134761853.392943
# [191/516]  dy_i = 87.13 * x + 31333.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 642320832.518258
# [192/516]  dy_i = 86.82 * x + 31112.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1433971827.455966
# [193/516]  dy_i = 87.84 * x + 31336.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 815223138.022289
# [194/516]  dy_i = 86.54 * x + 31317.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 519359046.181188
# [195/516]  dy_i = 85.13 * x + 30968.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2600777272.749551
# [196/516]  dy_i = 91.07 * x + 32100.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1905294485.142852
# [197/516]  dy_i = 89.28 * x + 31827.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2402803918.709410
# [198/516]  dy_i = 87.41 * x + 31368.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1006094082.493996
# [199/516]  dy_i = 92.70 * x + 32316.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1535418730.604088
# [200/516]  dy_i = 93.94 * x + 32090.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1066581919.824661
# [201/516]  dy_i = 88.85 * x + 30264.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1243443290.706806
# [202/516]  dy_i = 91.71 * x + 31375.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 803136856.158612
# [203/516]  dy_i = 88.88 * x + 31031.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1187490832.823288
# [204/516]  dy_i = 90.80 * x + 31941.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 816305137.380640
# [205/516]  dy_i = 88.89 * x + 31432.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1140469416.261365
# [206/516]  dy_i = 85.31 * x + 30521.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 895487744.950150
# [207/516]  dy_i = 84.05 * x + 31128.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1139972986.440929
# [208/516]  dy_i = 95.85 * x + 31212.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4917230285.884074
# [209/516]  dy_i = 96.89 * x + 31566.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1280580212.831496
# [210/516]  dy_i = 93.84 * x + 30874.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1139910917.718789
# [211/516]  dy_i = 89.26 * x + 29575.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 793002777.515447
# [212/516]  dy_i = 91.26 * x + 30617.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 985247332.629087
# [213/516]  dy_i = 91.72 * x + 31072.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1493215587.794715
# [214/516]  dy_i = 89.02 * x + 30196.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1033484965.345487
# [215/516]  dy_i = 91.58 * x + 31078.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 455246160.024963
# [216/516]  dy_i = 92.67 * x + 28655.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4992802760.276016
# [217/516]  dy_i = 91.06 * x + 28503.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 801036506.960184
# [218/516]  dy_i = 90.05 * x + 28231.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1613859237.273196
# [219/516]  dy_i = 91.68 * x + 29066.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 514503757.176686
# [220/516]  dy_i = 90.71 * x + 29979.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1328500390.123966
# [221/516]  dy_i = 91.61 * x + 30362.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1193371173.942654
# [222/516]  dy_i = 91.66 * x + 30749.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 806205954.851345
# [223/516]  dy_i = 88.73 * x + 29905.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1086892797.098419
# [224/516]  dy_i = 87.88 * x + 29900.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 841815317.012266
# [225/516]  dy_i = 91.12 * x + 31215.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 581594818.180507
# [226/516]  dy_i = 92.14 * x + 31088.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 648536207.163507
# [227/516]  dy_i = 86.85 * x + 30079.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1013611233.949508
# [228/516]  dy_i = 90.31 * x + 31125.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 991403860.792730
# [229/516]  dy_i = 95.97 * x + 30919.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 6763434614.997870
# [230/516]  dy_i = 94.92 * x + 30555.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 610518912.558805
# [231/516]  dy_i = 93.04 * x + 30012.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 702658456.664372
# [232/516]  dy_i = 86.76 * x + 28549.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 926956343.149956
# [233/516]  dy_i = 91.98 * x + 31404.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2417070656.380711
# [234/516]  dy_i = 93.43 * x + 31938.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1293173718.636372
# [235/516]  dy_i = 93.29 * x + 31803.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3368599633.188974
# [236/516]  dy_i = 93.51 * x + 32040.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1064797060.178642
# [237/516]  dy_i = 91.29 * x + 31440.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 749724759.747942
# [238/516]  dy_i = 91.93 * x + 32209.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1607759592.192461
# [239/516]  dy_i = 97.72 * x + 33234.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1225301246.676518
# [240/516]  dy_i = 94.45 * x + 32427.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2600201126.383041
# [241/516]  dy_i = 91.33 * x + 32107.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1349766871.888791
# [242/516]  dy_i = 92.78 * x + 32690.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 414454010.698793
# [243/516]  dy_i = 94.85 * x + 32227.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1788365580.688341
# [244/516]  dy_i = 89.85 * x + 30932.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1080329452.750351
# [245/516]  dy_i = 89.81 * x + 31208.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 599333558.915924
# [246/516]  dy_i = 97.88 * x + 30981.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4348451771.814597
# [247/516]  dy_i = 96.49 * x + 30389.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 915731359.545649
# [248/516]  dy_i = 93.72 * x + 29714.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 874593447.194610
# [249/516]  dy_i = 91.63 * x + 29483.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 935530334.220708
# [250/516]  dy_i = 89.69 * x + 29393.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 882663324.947953
# [251/516]  dy_i = 88.05 * x + 29365.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1038398168.487897
# [252/516]  dy_i = 86.02 * x + 28473.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 606519126.090509
# [253/516]  dy_i = 84.58 * x + 27841.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1110771021.771090
# [254/516]  dy_i = 87.80 * x + 28610.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1329017944.742076
# [255/516]  dy_i = 88.39 * x + 29045.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 992223012.408530
# [256/516]  dy_i = 90.68 * x + 30739.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2796156411.652677
# [257/516]  dy_i = 91.52 * x + 31386.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 659804033.756731
# [258/516]  dy_i = 89.67 * x + 30898.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1682497031.768564
# [259/516]  dy_i = 91.03 * x + 31245.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 853539799.934302
# [260/516]  dy_i = 90.12 * x + 31311.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 812479793.848813
# [261/516]  dy_i = 92.33 * x + 31399.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2093856213.544728
# [262/516]  dy_i = 89.19 * x + 30584.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 785899411.447345
# [263/516]  dy_i = 89.73 * x + 30910.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 582900091.441258
# [264/516]  dy_i = 96.47 * x + 29966.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4001835417.275475
# [265/516]  dy_i = 93.99 * x + 29004.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 682646347.594880
# [266/516]  dy_i = 93.78 * x + 29352.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153006590.414399
# [267/516]  dy_i = 93.31 * x + 29125.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 463175023.510277
# [268/516]  dy_i = 92.16 * x + 29037.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1370170514.986401
# [269/516]  dy_i = 90.16 * x + 27994.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 704668021.184817
# [270/516]  dy_i = 100.60 * x + 27599.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3436891948.891064
# [271/516]  dy_i = 99.39 * x + 26578.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1336809686.922096
# [272/516]  dy_i = 94.11 * x + 25914.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3241068656.263219
# [273/516]  dy_i = 97.44 * x + 27244.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1249302734.176414
# [274/516]  dy_i = 89.38 * x + 26539.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1573705117.789138
# [275/516]  dy_i = 89.64 * x + 27253.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1232228858.573581
# [276/516]  dy_i = 92.08 * x + 29453.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1880966981.886407
# [277/516]  dy_i = 88.20 * x + 28844.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1304096567.757749
# [278/516]  dy_i = 87.92 * x + 29374.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 942301482.357612
# [279/516]  dy_i = 87.08 * x + 29654.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1619112851.624108
# [280/516]  dy_i = 87.96 * x + 31502.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1127919795.271661
# [281/516]  dy_i = 90.07 * x + 32556.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1209132242.452892
# [282/516]  dy_i = 89.22 * x + 32273.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 968404251.720354
# [283/516]  dy_i = 89.91 * x + 30961.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2195542217.737680
# [284/516]  dy_i = 93.27 * x + 31167.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1444103941.498090
# [285/516]  dy_i = 89.35 * x + 31167.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3349479125.071137
# [286/516]  dy_i = 88.31 * x + 31165.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1037915067.908689
# [287/516]  dy_i = 88.77 * x + 31519.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211625237.099905
# [288/516]  dy_i = 91.01 * x + 32571.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 645618020.858570
# [289/516]  dy_i = 87.70 * x + 31537.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 787470715.841164
# [290/516]  dy_i = 88.17 * x + 32406.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 891891774.089950
# [291/516]  dy_i = 85.18 * x + 31985.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1462797204.448404
# [292/516]  dy_i = 86.05 * x + 32718.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1212918154.589581
# [293/516]  dy_i = 83.64 * x + 32809.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1276205634.090866
# [294/516]  dy_i = 82.38 * x + 33205.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 958077003.523074
# [295/516]  dy_i = 97.17 * x + 34188.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4754804070.557921
# [296/516]  dy_i = 97.30 * x + 33458.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1039521283.298576
# [297/516]  dy_i = 96.44 * x + 32494.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 723405225.407855
# [298/516]  dy_i = 92.95 * x + 31388.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709827627.575549
# [299/516]  dy_i = 89.76 * x + 30149.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 747562220.818274
# [300/516]  dy_i = 90.13 * x + 30232.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 923081789.469275
# [301/516]  dy_i = 92.27 * x + 31818.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 840874590.636266
# [302/516]  dy_i = 86.55 * x + 30812.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1546347643.954222
# [303/516]  dy_i = 91.12 * x + 33180.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3495880458.069507
# [304/516]  dy_i = 97.53 * x + 32368.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4676734705.515245
# [305/516]  dy_i = 93.13 * x + 30429.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 628718742.971460
# [306/516]  dy_i = 96.80 * x + 31334.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2943777916.428086
# [307/516]  dy_i = 91.80 * x + 30049.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1193574993.624834
# [308/516]  dy_i = 90.34 * x + 29761.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1006548130.668469
# [309/516]  dy_i = 95.94 * x + 29428.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4700268135.761091
# [310/516]  dy_i = 101.47 * x + 27704.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3398054618.814000
# [311/516]  dy_i = 95.70 * x + 25911.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 754450394.644649
# [312/516]  dy_i = 94.75 * x + 25727.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 790676712.163618
# [313/516]  dy_i = 94.17 * x + 25338.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1770939825.610661
# [314/516]  dy_i = 91.09 * x + 24768.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1233684482.091829
# [315/516]  dy_i = 93.83 * x + 26186.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1171143987.462804
# [316/516]  dy_i = 94.13 * x + 26491.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1493949049.833597
# [317/516]  dy_i = 97.22 * x + 27079.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1426651419.247048
# [318/516]  dy_i = 102.20 * x + 25516.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4134900811.389002
# [319/516]  dy_i = 99.59 * x + 24176.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 580175055.076833
# [320/516]  dy_i = 98.44 * x + 24426.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 585008840.747394
# [321/516]  dy_i = 97.35 * x + 24509.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1235442588.153108
# [322/516]  dy_i = 93.08 * x + 23745.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1225041594.991511
# [323/516]  dy_i = 90.09 * x + 23292.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 738759004.530255
# [324/516]  dy_i = 95.34 * x + 25097.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1750678160.620185
# [325/516]  dy_i = 91.44 * x + 24092.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 755858291.727431
# [326/516]  dy_i = 97.59 * x + 26053.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1667413103.918390
# [327/516]  dy_i = 98.09 * x + 24595.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4946623405.802118
# [328/516]  dy_i = 96.32 * x + 24242.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 641978109.695039
# [329/516]  dy_i = 94.50 * x + 24942.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1962520069.579886
# [330/516]  dy_i = 87.15 * x + 24486.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1854708247.086244
# [331/516]  dy_i = 93.43 * x + 26311.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1476240849.479145
# [332/516]  dy_i = 100.40 * x + 25603.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3765344657.487371
# [333/516]  dy_i = 90.56 * x + 23226.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1303233774.777648
# [334/516]  dy_i = 89.10 * x + 23126.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 926211791.861595
# [335/516]  dy_i = 90.28 * x + 23650.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 813527894.149815
# [336/516]  dy_i = 92.01 * x + 24666.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1098135845.924299
# [337/516]  dy_i = 91.45 * x + 25193.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 967449750.594545
# [338/516]  dy_i = 95.14 * x + 26138.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1048986293.135584
# [339/516]  dy_i = 95.15 * x + 25862.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1522971994.227881
# [340/516]  dy_i = 90.58 * x + 24505.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 974236562.846004
# [341/516]  dy_i = 91.28 * x + 24691.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 875475856.005118
# [342/516]  dy_i = 99.05 * x + 23984.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3664126319.390771
# [343/516]  dy_i = 98.30 * x + 23196.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1276506527.953635
# [344/516]  dy_i = 96.83 * x + 22950.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1118511898.805005
# [345/516]  dy_i = 96.62 * x + 22928.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 664556543.658750
# [346/516]  dy_i = 95.44 * x + 22302.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1194109630.941355
# [347/516]  dy_i = 94.05 * x + 22789.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1743883507.367703
# [348/516]  dy_i = 99.25 * x + 23863.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1311768937.761953
# [349/516]  dy_i = 91.60 * x + 21108.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 6690137863.094384
# [350/516]  dy_i = 84.95 * x + 20782.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1336352720.331257
# [351/516]  dy_i = 91.52 * x + 22735.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2330111131.743726
# [352/516]  dy_i = 93.51 * x + 23729.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1207422712.646894
# [353/516]  dy_i = 97.92 * x + 25342.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1838508447.969562
# [354/516]  dy_i = 87.38 * x + 23794.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1556023639.141815
# [355/516]  dy_i = 91.44 * x + 26217.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2520725223.547561
# [356/516]  dy_i = 89.81 * x + 26079.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 886370912.761046
# [357/516]  dy_i = 95.32 * x + 25112.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4569949297.643804
# [358/516]  dy_i = 97.10 * x + 25731.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1125816987.418333
# [359/516]  dy_i = 101.52 * x + 26974.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2694227755.550752
# [360/516]  dy_i = 98.43 * x + 26170.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2484952046.227390
# [361/516]  dy_i = 94.20 * x + 25904.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1285551973.017534
# [362/516]  dy_i = 94.95 * x + 26358.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 967582304.782086
# [363/516]  dy_i = 96.93 * x + 26994.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1621680737.245659
# [364/516]  dy_i = 90.32 * x + 25790.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1177805016.900116
# [365/516]  dy_i = 91.35 * x + 26785.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1233892249.254411
# [366/516]  dy_i = 88.35 * x + 26860.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1295584441.782981
# [367/516]  dy_i = 89.66 * x + 27683.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 808439825.916191
# [368/516]  dy_i = 93.63 * x + 28641.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467205518.147116
# [369/516]  dy_i = 90.17 * x + 27848.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 907295929.000772
# [370/516]  dy_i = 92.18 * x + 28677.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 974075897.284974
# [371/516]  dy_i = 86.83 * x + 28714.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1480668893.096978
# [372/516]  dy_i = 89.91 * x + 29618.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 712080500.230049
# [373/516]  dy_i = 86.68 * x + 29290.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1761173652.446980
# [374/516]  dy_i = 84.71 * x + 29119.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1582942553.374158
# [375/516]  dy_i = 88.07 * x + 31315.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3406196317.132491
# [376/516]  dy_i = 86.83 * x + 31363.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1336103550.241332
# [377/516]  dy_i = 89.04 * x + 31617.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1899806188.633586
# [378/516]  dy_i = 87.03 * x + 31057.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1095574638.736618
# [379/516]  dy_i = 87.03 * x + 31581.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1258124861.128001
# [380/516]  dy_i = 95.90 * x + 30646.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3937773461.228735
# [381/516]  dy_i = 94.21 * x + 29919.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 489339985.049895
# [382/516]  dy_i = 93.71 * x + 30285.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 786232595.605998
# [383/516]  dy_i = 93.60 * x + 30607.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1157979208.771620
# [384/516]  dy_i = 94.41 * x + 30731.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1084231744.825975
# [385/516]  dy_i = 94.80 * x + 30417.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 663923258.795887
# [386/516]  dy_i = 89.19 * x + 29521.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1749066159.128257
# [387/516]  dy_i = 88.49 * x + 28889.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1073082895.364758
# [388/516]  dy_i = 91.53 * x + 29949.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708284679.202900
# [389/516]  dy_i = 88.49 * x + 29473.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2138054228.185034
# [390/516]  dy_i = 88.24 * x + 30616.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1573473860.347034
# [391/516]  dy_i = 89.85 * x + 30818.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 969583101.156715
# [392/516]  dy_i = 86.25 * x + 30886.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1308271040.559459
# [393/516]  dy_i = 101.62 * x + 31767.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3136416045.404370
# [394/516]  dy_i = 94.58 * x + 29912.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1595369014.554830
# [395/516]  dy_i = 92.63 * x + 29812.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 946916506.815625
# [396/516]  dy_i = 89.08 * x + 29064.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 582390793.915981
# [397/516]  dy_i = 92.90 * x + 30516.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3069236877.153089
# [398/516]  dy_i = 91.00 * x + 29676.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1154480964.453698
# [399/516]  dy_i = 92.75 * x + 30817.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1039030489.919597
# [400/516]  dy_i = 93.06 * x + 31042.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 515144306.717018
# [401/516]  dy_i = 95.50 * x + 30755.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 890351109.959930
# [402/516]  dy_i = 92.14 * x + 30074.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1294536516.017507
# [403/516]  dy_i = 90.18 * x + 29770.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1450636918.395169
# [404/516]  dy_i = 99.37 * x + 31296.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1727057489.767002
# [405/516]  dy_i = 99.84 * x + 31153.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2426264806.360336
# [406/516]  dy_i = 90.06 * x + 29746.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1738753672.074975
# [407/516]  dy_i = 88.93 * x + 29597.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 666722529.994067
# [408/516]  dy_i = 88.84 * x + 30096.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 773912431.948348
# [409/516]  dy_i = 89.86 * x + 30269.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 613786038.245966
# [410/516]  dy_i = 90.04 * x + 30415.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 670499065.117459
# [411/516]  dy_i = 88.91 * x + 30567.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 970189502.380533
# [412/516]  dy_i = 88.69 * x + 31294.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 897415865.804572
# [413/516]  dy_i = 89.92 * x + 31879.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1441061297.898509
# [414/516]  dy_i = 86.79 * x + 32075.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1641869806.289005
# [415/516]  dy_i = 86.82 * x + 31910.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 717484077.000025
# [416/516]  dy_i = 89.35 * x + 32847.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1336359020.146815
# [417/516]  dy_i = 89.08 * x + 33023.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 890341577.091177
# [418/516]  dy_i = 97.55 * x + 32290.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4515480729.712719
# [419/516]  dy_i = 91.88 * x + 30878.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403199893.067627
# [420/516]  dy_i = 100.30 * x + 30586.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4266352847.639466
# [421/516]  dy_i = 94.45 * x + 28946.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1392946379.838080
# [422/516]  dy_i = 104.71 * x + 28242.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3285756496.839554
# [423/516]  dy_i = 97.11 * x + 25723.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1056701755.372294
# [424/516]  dy_i = 95.39 * x + 25915.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2893905992.504251
# [425/516]  dy_i = 99.52 * x + 26592.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640917573.938406
# [426/516]  dy_i = 93.34 * x + 25087.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1014690004.086190
# [427/516]  dy_i = 95.85 * x + 25976.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 455679229.343041
# [428/516]  dy_i = 97.07 * x + 27083.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1437719480.420817
# [429/516]  dy_i = 92.69 * x + 25824.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1643962728.168571
# [430/516]  dy_i = 89.94 * x + 25684.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 960254601.737185
# [431/516]  dy_i = 93.26 * x + 27046.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1376517186.949692
# [432/516]  dy_i = 90.66 * x + 26554.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1492153402.628351
# [433/516]  dy_i = 100.37 * x + 26945.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3310101915.009134
# [434/516]  dy_i = 96.16 * x + 26127.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1357712227.267905
# [435/516]  dy_i = 96.15 * x + 26202.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 682850280.800288
# [436/516]  dy_i = 96.23 * x + 26408.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1289153512.260405
# [437/516]  dy_i = 98.33 * x + 26369.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1120891957.523223
# [438/516]  dy_i = 93.86 * x + 25646.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638573750.172276
# [439/516]  dy_i = 92.90 * x + 25838.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1176882668.864983
# [440/516]  dy_i = 91.60 * x + 26587.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1444555629.367059
# [441/516]  dy_i = 87.15 * x + 25800.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1151058387.697150
# [442/516]  dy_i = 91.14 * x + 27600.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2483170153.255551
# [443/516]  dy_i = 93.41 * x + 28551.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1717763746.607871
# [444/516]  dy_i = 92.23 * x + 28293.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 562301293.000134
# [445/516]  dy_i = 91.68 * x + 27902.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 619587394.550632
# [446/516]  dy_i = 89.58 * x + 27421.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1061936988.561122
# [447/516]  dy_i = 91.32 * x + 28775.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1035438791.494389
# [448/516]  dy_i = 96.16 * x + 27834.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4729497250.248625
# [449/516]  dy_i = 93.29 * x + 27723.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2716014224.905413
# [450/516]  dy_i = 92.24 * x + 27858.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1083797341.847950
# [451/516]  dy_i = 89.14 * x + 27318.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1852694978.512461
# [452/516]  dy_i = 91.73 * x + 28158.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 945650346.433399
# [453/516]  dy_i = 92.24 * x + 28242.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1362081781.074537
# [454/516]  dy_i = 91.93 * x + 28439.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 994372947.253753
# [455/516]  dy_i = 92.63 * x + 28989.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1167920000.138427
# [456/516]  dy_i = 91.43 * x + 28507.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 745316146.560647
# [457/516]  dy_i = 93.83 * x + 29184.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1193075079.434822
# [458/516]  dy_i = 90.23 * x + 28192.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1166189174.388974
# [459/516]  dy_i = 97.16 * x + 30693.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3507090744.429288
# [460/516]  dy_i = 99.05 * x + 29400.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4241946579.759582
# [461/516]  dy_i = 96.88 * x + 28827.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 620516061.759633
# [462/516]  dy_i = 93.33 * x + 28456.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1304038624.756323
# [463/516]  dy_i = 95.05 * x + 27864.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1148075755.038061
# [464/516]  dy_i = 93.71 * x + 26831.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 982971314.986872
# [465/516]  dy_i = 101.44 * x + 26270.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4286155411.913057
# [466/516]  dy_i = 96.10 * x + 24997.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 651306028.188321
# [467/516]  dy_i = 94.33 * x + 24424.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 947741132.762012
# [468/516]  dy_i = 96.69 * x + 24898.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 430089517.808272
# [469/516]  dy_i = 97.09 * x + 25440.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1053287029.560530
# [470/516]  dy_i = 97.84 * x + 25537.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1279232258.710236
# [471/516]  dy_i = 95.04 * x + 24811.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1246516830.963324
# [472/516]  dy_i = 92.96 * x + 24848.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1222029073.271741
# [473/516]  dy_i = 93.09 * x + 26071.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1023596980.840866
# [474/516]  dy_i = 93.06 * x + 26208.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1258425685.834507
# [475/516]  dy_i = 92.85 * x + 27223.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1659766561.670131
# [476/516]  dy_i = 91.50 * x + 26953.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 717825330.466619
# [477/516]  dy_i = 90.30 * x + 27270.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1044508629.496117
# [478/516]  dy_i = 92.38 * x + 28085.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1006984022.525405
# [479/516]  dy_i = 92.51 * x + 28332.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 861061381.401475
# [480/516]  dy_i = 92.87 * x + 28766.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1162548789.099298
# [481/516]  dy_i = 91.84 * x + 28095.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 819219714.805317
# [482/516]  dy_i = 88.59 * x + 28073.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1089449844.627841
# [483/516]  dy_i = 89.61 * x + 29144.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1613576285.211234
# [484/516]  dy_i = 91.65 * x + 30696.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2704855743.561671
# [485/516]  dy_i = 90.70 * x + 30437.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 957623168.596272
# [486/516]  dy_i = 89.05 * x + 30663.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1430031929.260352
# [487/516]  dy_i = 87.09 * x + 29549.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1335530086.993102
# [488/516]  dy_i = 88.06 * x + 30478.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1358583714.119500
# [489/516]  dy_i = 88.17 * x + 31269.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1108367604.765483
# [490/516]  dy_i = 94.00 * x + 30368.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4615121979.551082
# [491/516]  dy_i = 86.77 * x + 28456.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1117093136.919909
# [492/516]  dy_i = 87.56 * x + 29119.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 717549751.083921
# [493/516]  dy_i = 86.34 * x + 29468.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1961785616.451400
# [494/516]  dy_i = 96.30 * x + 29573.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4799694650.987651
# [495/516]  dy_i = 92.85 * x + 28149.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 849894783.991771
# [496/516]  dy_i = 91.54 * x + 28726.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1098200417.762398
# [497/516]  dy_i = 99.73 * x + 30943.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3021032837.135128
# [498/516]  dy_i = 98.23 * x + 30071.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1166908191.608811
# [499/516]  dy_i = 94.73 * x + 28885.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 789659188.024574
# [500/516]  dy_i = 91.05 * x + 28532.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1151728934.927633
# [501/516]  dy_i = 88.12 * x + 28525.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1146584823.951675
# [502/516]  dy_i = 91.02 * x + 29905.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1095676298.120998
# [503/516]  dy_i = 90.93 * x + 30373.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1156867878.313822
# [504/516]  dy_i = 89.38 * x + 29928.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 868720523.536124
# [505/516]  dy_i = 89.76 * x + 30283.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1377214851.508137
# [506/516]  dy_i = 88.69 * x + 30727.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406603326.407064
# [507/516]  dy_i = 88.46 * x + 31530.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1716218007.588441
# [508/516]  dy_i = 88.94 * x + 32094.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 678783575.238446
# [509/516]  dy_i = 87.66 * x + 32617.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1751465030.141105
# [510/516]  dy_i = 101.35 * x + 32652.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3742510316.631725
# [511/516]  dy_i = 93.05 * x + 30109.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1171346491.637773
# [512/516]  dy_i = 90.60 * x + 29700.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 798975755.762236
# [513/516]  dy_i = 88.39 * x + 30151.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1421795899.280273
# [514/516]  dy_i = 97.83 * x + 30207.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3958571010.404984
# [515/516]  dy_i = 93.09 * x + 29106.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1225208358.225574

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []
#define a batch size
batch_size = 64
# we run our loop N times
loop_N = 30*len(data)//batch_size
for i in range(loop_N):
   # We just want a sample of the dataset with batch_size size
   data_batch = data.sample(batch_size)
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()

   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d/%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,loop_N,m,b,m_calc,b_calc,loss_value))

# close/delete previous plots
plt.close('all')

# create a 1 by 2 plot grid
fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
# lot our usual output
plot_data(data_x,data_y,m,b,ax[0])

# here we also plot the calculated linear fit for comparison
line_x = np.arange(data_x.min(),data_x.max())
line_y = line_x * m_calc + b_calc
ax[0].plot(line_x,line_y,'b-',label='calculated')
# add a legend to the plot and x/y labels
ax[0].legend()
ax[0].set_xlabel('square footage')
ax[0].set_ylabel('sale price')

# plot the loss
loss_x = np.arange(0,len(loss_history))
loss_y = np.asarray(loss_history)
ax[1].plot(loss_x,loss_y, 'o-')
ax[1].set_yscale('log')
ax[1].set_xlabel('loop step')
ax[1].set_ylabel('loss')
plt.show()
# gives us time to see the plot
time.sleep(2.5)
# clears the plot when the next plot is ready to show.
ipydis.clear_output(wait=True)
# Out:
# [000/258]  dy_i = 58.45 * x + 16570.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 5982320627.320662
# [001/258]  dy_i = 76.12 * x + 23431.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1728099456.580478
# [002/258]  dy_i = 85.80 * x + 26656.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2131897452.539433
# [003/258]  dy_i = 87.30 * x + 27363.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 748448829.938175
# [004/258]  dy_i = 88.69 * x + 28145.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1024115931.900278
# [005/258]  dy_i = 93.08 * x + 29089.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1553643804.516281
# [006/258]  dy_i = 91.64 * x + 28623.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 857574667.737833
# [007/258]  dy_i = 94.20 * x + 29582.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2411655658.448565
# [008/258]  dy_i = 91.15 * x + 28713.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1048335717.701314
# [009/258]  dy_i = 91.16 * x + 28932.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 900234351.759609
# [010/258]  dy_i = 92.62 * x + 29570.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1689220759.177886
# [011/258]  dy_i = 91.51 * x + 29236.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1255147473.860533
# [012/258]  dy_i = 90.51 * x + 29625.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1925680428.748540
# [013/258]  dy_i = 89.89 * x + 29379.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 980421087.815835
# [014/258]  dy_i = 90.67 * x + 30436.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1018791040.747229
# [015/258]  dy_i = 93.84 * x + 30965.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3421616903.332112
# [016/258]  dy_i = 95.02 * x + 30360.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3818747180.892755
# [017/258]  dy_i = 90.81 * x + 29313.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1060183737.126478
# [018/258]  dy_i = 90.24 * x + 29301.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 997748032.411914
# [019/258]  dy_i = 89.60 * x + 29362.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1055622255.828408
# [020/258]  dy_i = 91.68 * x + 29953.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 995404209.984786
# [021/258]  dy_i = 92.30 * x + 30316.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1075450422.995543
# [022/258]  dy_i = 90.11 * x + 30100.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1127778574.566171
# [023/258]  dy_i = 92.40 * x + 30722.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 822480353.815509
# [024/258]  dy_i = 88.53 * x + 29767.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 701715774.608339
# [025/258]  dy_i = 87.89 * x + 30219.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1821407907.743903
# [026/258]  dy_i = 90.03 * x + 30840.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1547644163.173299
# [027/258]  dy_i = 92.09 * x + 31818.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 860363279.833618
# [028/258]  dy_i = 90.36 * x + 31272.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1313576339.183670
# [029/258]  dy_i = 91.01 * x + 30629.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3403986530.682272
# [030/258]  dy_i = 94.40 * x + 31008.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2697322656.879187
# [031/258]  dy_i = 94.70 * x + 31027.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2039293447.012810
# [032/258]  dy_i = 95.68 * x + 30074.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3109021725.205970
# [033/258]  dy_i = 95.25 * x + 29936.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 797580979.138112
# [034/258]  dy_i = 91.88 * x + 29407.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1889185122.808769
# [035/258]  dy_i = 90.91 * x + 29672.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1851983870.402184
# [036/258]  dy_i = 93.62 * x + 30717.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 922036575.320997
# [037/258]  dy_i = 91.68 * x + 30178.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1600753801.911265
# [038/258]  dy_i = 90.14 * x + 29838.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1575527473.337336
# [039/258]  dy_i = 85.80 * x + 29339.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1323675920.857855
# [040/258]  dy_i = 86.60 * x + 30023.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1255828241.616467
# [041/258]  dy_i = 84.89 * x + 30710.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 913341346.169169
# [042/258]  dy_i = 85.55 * x + 31153.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1112553004.973977
# [043/258]  dy_i = 90.80 * x + 31309.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3782334677.641081
# [044/258]  dy_i = 91.42 * x + 30753.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1306540259.630238
# [045/258]  dy_i = 90.18 * x + 30433.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 956797785.534487
# [046/258]  dy_i = 89.36 * x + 30820.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1043990537.261362
# [047/258]  dy_i = 88.80 * x + 31350.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1259212321.852806
# [048/258]  dy_i = 90.11 * x + 31747.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1911743042.838956
# [049/258]  dy_i = 86.70 * x + 30799.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1163814473.571707
# [050/258]  dy_i = 89.31 * x + 32176.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2301176776.418862
# [051/258]  dy_i = 86.68 * x + 31505.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 993186574.664311
# [052/258]  dy_i = 89.88 * x + 31108.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2767441740.342379
# [053/258]  dy_i = 88.90 * x + 30912.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 809118161.514422
# [054/258]  dy_i = 88.94 * x + 30725.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1184993352.160738
# [055/258]  dy_i = 91.43 * x + 31964.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1924338471.351144
# [056/258]  dy_i = 87.15 * x + 31257.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1174461832.021208
# [057/258]  dy_i = 87.15 * x + 31956.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1057688850.597605
# [058/258]  dy_i = 88.20 * x + 32575.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1161835590.540655
# [059/258]  dy_i = 91.11 * x + 33957.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1706460912.068812
# [060/258]  dy_i = 90.85 * x + 33615.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1392765497.553538
# [061/258]  dy_i = 88.14 * x + 32894.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1521955311.710549
# [062/258]  dy_i = 86.81 * x + 32818.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 937256538.497641
# [063/258]  dy_i = 88.79 * x + 31982.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3115421114.979344
# [064/258]  dy_i = 83.85 * x + 31642.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1073882416.707128
# [065/258]  dy_i = 83.34 * x + 31368.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1351040727.114840
# [066/258]  dy_i = 84.68 * x + 32154.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 881748106.719656
# [067/258]  dy_i = 83.98 * x + 32782.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1391525676.555075
# [068/258]  dy_i = 86.54 * x + 34041.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1193725318.341439
# [069/258]  dy_i = 86.80 * x + 34318.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1281631860.055912
# [070/258]  dy_i = 87.13 * x + 34434.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1160144564.478299
# [071/258]  dy_i = 87.80 * x + 34866.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 731860739.385470
# [072/258]  dy_i = 94.77 * x + 34958.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2821514340.457446
# [073/258]  dy_i = 90.61 * x + 33322.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1630472053.329597
# [074/258]  dy_i = 87.63 * x + 32930.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 967591564.302212
# [075/258]  dy_i = 84.92 * x + 33166.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2453658671.960461
# [076/258]  dy_i = 87.68 * x + 34456.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 740112411.184504
# [077/258]  dy_i = 91.61 * x + 34453.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2580657705.256427
# [078/258]  dy_i = 88.87 * x + 33892.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1433751713.690329
# [079/258]  dy_i = 86.65 * x + 33806.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1886245020.282282
# [080/258]  dy_i = 86.49 * x + 34139.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 745917525.985127
# [081/258]  dy_i = 87.54 * x + 34558.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1091032768.921933
# [082/258]  dy_i = 86.51 * x + 34576.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1078686033.019785
# [083/258]  dy_i = 88.83 * x + 34914.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1196729240.159009
# [084/258]  dy_i = 87.85 * x + 34998.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 860099151.593981
# [085/258]  dy_i = 87.62 * x + 34971.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1478703162.257234
# [086/258]  dy_i = 86.19 * x + 34617.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 878810906.041897
# [087/258]  dy_i = 92.60 * x + 35075.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3257792009.467791
# [088/258]  dy_i = 91.53 * x + 34804.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1250909043.580014
# [089/258]  dy_i = 88.87 * x + 33874.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 968288518.791207
# [090/258]  dy_i = 89.19 * x + 33960.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1076350521.570077
# [091/258]  dy_i = 87.30 * x + 33624.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1172041004.840457
# [092/258]  dy_i = 91.17 * x + 34246.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2464376256.175234
# [093/258]  dy_i = 90.58 * x + 34349.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1526433666.091114
# [094/258]  dy_i = 87.48 * x + 33234.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1151162651.414403
# [095/258]  dy_i = 85.70 * x + 33617.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1482910232.865268
# [096/258]  dy_i = 86.42 * x + 34532.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1527641463.801509
# [097/258]  dy_i = 87.50 * x + 34725.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1451353469.353620
# [098/258]  dy_i = 85.64 * x + 34668.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 952024839.049507
# [099/258]  dy_i = 83.46 * x + 34348.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1243746107.432881
# [100/258]  dy_i = 87.26 * x + 34082.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2642728137.761089
# [101/258]  dy_i = 87.71 * x + 34333.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 801875889.136155
# [102/258]  dy_i = 93.32 * x + 34205.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3599073067.211322
# [103/258]  dy_i = 89.13 * x + 33221.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1202184000.693551
# [104/258]  dy_i = 96.51 * x + 33869.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3894864910.443357
# [105/258]  dy_i = 92.62 * x + 32756.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1115119993.067402
# [106/258]  dy_i = 87.93 * x + 31763.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 963961537.313658
# [107/258]  dy_i = 88.25 * x + 32139.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 911217918.505953
# [108/258]  dy_i = 88.25 * x + 32741.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1084398556.945900
# [109/258]  dy_i = 88.92 * x + 32163.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1009648310.021230
# [110/258]  dy_i = 89.00 * x + 32454.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1646599275.087138
# [111/258]  dy_i = 90.39 * x + 33165.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1094766865.194504
# [112/258]  dy_i = 87.84 * x + 32982.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1431184727.393426
# [113/258]  dy_i = 86.03 * x + 32740.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 902060629.437480
# [114/258]  dy_i = 86.70 * x + 33701.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637279166.038280
# [115/258]  dy_i = 83.85 * x + 33786.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1231779066.139190
# [116/258]  dy_i = 84.16 * x + 34405.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1508129389.035363
# [117/258]  dy_i = 84.99 * x + 34812.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 961922513.311474
# [118/258]  dy_i = 86.87 * x + 35652.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 937882958.720225
# [119/258]  dy_i = 88.25 * x + 36069.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1667698438.849090
# [120/258]  dy_i = 85.56 * x + 35061.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1099413317.334226
# [121/258]  dy_i = 88.25 * x + 35124.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1655121344.105829
# [122/258]  dy_i = 88.43 * x + 35367.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 841535157.555875
# [123/258]  dy_i = 87.85 * x + 35081.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1252627314.723435
# [124/258]  dy_i = 86.47 * x + 34878.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 697669539.844684
# [125/258]  dy_i = 85.76 * x + 35356.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2181047095.358903
# [126/258]  dy_i = 90.35 * x + 36036.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1007353991.916471
# [127/258]  dy_i = 94.68 * x + 35501.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2378958528.001997
# [128/258]  dy_i = 89.38 * x + 34057.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1064684343.620090
# [129/258]  dy_i = 89.55 * x + 33964.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2211554536.470028
# [130/258]  dy_i = 88.20 * x + 33316.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1133324520.183874
# [131/258]  dy_i = 87.44 * x + 33655.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 973560834.603318
# [132/258]  dy_i = 86.51 * x + 33672.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1383178005.120512
# [133/258]  dy_i = 87.09 * x + 33726.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626038439.565887
# [134/258]  dy_i = 85.64 * x + 33245.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1156257486.225015
# [135/258]  dy_i = 83.84 * x + 33344.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1291017949.312851
# [136/258]  dy_i = 86.24 * x + 34459.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 996938387.756691
# [137/258]  dy_i = 93.74 * x + 35201.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2951411135.510234
# [138/258]  dy_i = 89.11 * x + 33719.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1052828449.555287
# [139/258]  dy_i = 88.08 * x + 33612.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1309098944.288412
# [140/258]  dy_i = 84.13 * x + 33154.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1270431770.793652
# [141/258]  dy_i = 90.35 * x + 33180.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2893614451.726255
# [142/258]  dy_i = 87.87 * x + 32804.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1128986368.937038
# [143/258]  dy_i = 84.65 * x + 32906.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1454036375.311964
# [144/258]  dy_i = 85.63 * x + 33481.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1347504942.232996
# [145/258]  dy_i = 89.23 * x + 33047.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2604924199.763686
# [146/258]  dy_i = 88.76 * x + 33561.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2293133713.527021
# [147/258]  dy_i = 88.10 * x + 33509.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1310427496.418736
# [148/258]  dy_i = 85.05 * x + 33184.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1327920676.762055
# [149/258]  dy_i = 86.51 * x + 33633.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1724128842.761468
# [150/258]  dy_i = 86.96 * x + 34144.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2218436428.904923
# [151/258]  dy_i = 86.53 * x + 34287.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 885088138.498010
# [152/258]  dy_i = 88.88 * x + 33517.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2709987949.423522
# [153/258]  dy_i = 87.76 * x + 32876.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1128534046.358374
# [154/258]  dy_i = 85.56 * x + 32493.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1460403799.053640
# [155/258]  dy_i = 89.56 * x + 34027.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1123592385.275679
# [156/258]  dy_i = 87.86 * x + 34060.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1000930498.912621
# [157/258]  dy_i = 87.84 * x + 33895.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1275699276.274011
# [158/258]  dy_i = 86.22 * x + 34178.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 961668410.032912
# [159/258]  dy_i = 85.63 * x + 34696.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1842088714.027493
# [160/258]  dy_i = 87.96 * x + 35441.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1158318355.686664
# [161/258]  dy_i = 89.55 * x + 36054.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 965132356.786530
# [162/258]  dy_i = 89.38 * x + 35901.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1252860735.404360
# [163/258]  dy_i = 91.00 * x + 34834.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3243928928.547675
# [164/258]  dy_i = 90.15 * x + 34669.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1232729740.060253
# [165/258]  dy_i = 91.47 * x + 33884.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2749366638.882270
# [166/258]  dy_i = 87.75 * x + 33538.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2027976673.768166
# [167/258]  dy_i = 91.33 * x + 32710.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2972364049.737190
# [168/258]  dy_i = 88.98 * x + 32494.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1266154953.610271
# [169/258]  dy_i = 91.09 * x + 33140.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 567020465.169125
# [170/258]  dy_i = 90.42 * x + 32987.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2022430424.417911
# [171/258]  dy_i = 88.04 * x + 33162.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248887017.573447
# [172/258]  dy_i = 96.02 * x + 33806.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3241250604.417032
# [173/258]  dy_i = 94.12 * x + 33317.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1078695117.958751
# [174/258]  dy_i = 89.46 * x + 31790.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1299958011.433555
# [175/258]  dy_i = 86.34 * x + 31187.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1392960524.811697
# [176/258]  dy_i = 85.76 * x + 31705.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 906120932.059625
# [177/258]  dy_i = 88.00 * x + 32419.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1344810820.078804
# [178/258]  dy_i = 85.92 * x + 31893.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1198769502.776994
# [179/258]  dy_i = 87.76 * x + 32076.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1351712609.127503
# [180/258]  dy_i = 89.15 * x + 32371.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1128763957.820840
# [181/258]  dy_i = 90.44 * x + 32710.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1024101609.867456
# [182/258]  dy_i = 90.22 * x + 32615.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 995298376.424036
# [183/258]  dy_i = 85.46 * x + 31574.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1386559388.016629
# [184/258]  dy_i = 86.82 * x + 32616.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1117785794.963478
# [185/258]  dy_i = 86.55 * x + 33311.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1134234067.634373
# [186/258]  dy_i = 87.55 * x + 33771.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1299327444.793493
# [187/258]  dy_i = 84.67 * x + 33237.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 908986486.223585
# [188/258]  dy_i = 86.90 * x + 34463.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1240032903.087078
# [189/258]  dy_i = 84.86 * x + 34168.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1364439019.881861
# [190/258]  dy_i = 86.35 * x + 34900.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1048820422.089074
# [191/258]  dy_i = 84.69 * x + 35336.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1136804204.885552
# [192/258]  dy_i = 81.99 * x + 34805.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 967130268.379745
# [193/258]  dy_i = 85.79 * x + 35520.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1317618746.118809
# [194/258]  dy_i = 89.33 * x + 35263.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3396559369.566711
# [195/258]  dy_i = 88.49 * x + 35384.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1144184592.916699
# [196/258]  dy_i = 87.51 * x + 35350.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1129419974.062218
# [197/258]  dy_i = 86.23 * x + 34863.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 750216311.255659
# [198/258]  dy_i = 85.36 * x + 35314.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 847238812.708790
# [199/258]  dy_i = 86.79 * x + 35694.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 847006994.130805
# [200/258]  dy_i = 85.92 * x + 35784.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1129223882.825034
# [201/258]  dy_i = 92.43 * x + 35651.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2843935143.935623
# [202/258]  dy_i = 87.92 * x + 34046.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 851108171.221044
# [203/258]  dy_i = 87.63 * x + 34622.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1912368992.158358
# [204/258]  dy_i = 86.82 * x + 34435.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467024882.533679
# [205/258]  dy_i = 86.60 * x + 34882.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1593746247.483691
# [206/258]  dy_i = 85.30 * x + 35009.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1360554224.552592
# [207/258]  dy_i = 86.18 * x + 35576.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 897546094.207046
# [208/258]  dy_i = 87.65 * x + 36122.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2321150724.790355
# [209/258]  dy_i = 88.56 * x + 36499.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1163701035.694721
# [210/258]  dy_i = 89.43 * x + 36928.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1073829629.205350
# [211/258]  dy_i = 88.12 * x + 36452.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1260503101.578568
# [212/258]  dy_i = 86.18 * x + 36194.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211129576.037311
# [213/258]  dy_i = 86.46 * x + 36469.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1208712120.081605
# [214/258]  dy_i = 87.57 * x + 36454.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 921801176.243692
# [215/258]  dy_i = 84.94 * x + 36092.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1123866764.980929
# [216/258]  dy_i = 85.45 * x + 36278.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 446612801.510689
# [217/258]  dy_i = 82.98 * x + 35929.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 975228098.633538
# [218/258]  dy_i = 81.96 * x + 35565.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 973084779.002562
# [219/258]  dy_i = 81.70 * x + 36162.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1533199346.451200
# [220/258]  dy_i = 83.57 * x + 37496.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1905903947.441420
# [221/258]  dy_i = 83.68 * x + 37746.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 856635801.013302
# [222/258]  dy_i = 86.84 * x + 38505.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1436497255.357830
# [223/258]  dy_i = 87.05 * x + 37955.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1159297570.315711
# [224/258]  dy_i = 87.28 * x + 38172.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 841453777.132087
# [225/258]  dy_i = 85.45 * x + 37388.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1301357947.687574
# [226/258]  dy_i = 85.42 * x + 38141.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1166594566.238073
# [227/258]  dy_i = 89.27 * x + 38902.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1080645592.849752
# [228/258]  dy_i = 86.97 * x + 38268.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1282265150.369389
# [229/258]  dy_i = 86.43 * x + 38023.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 862355836.748248
# [230/258]  dy_i = 81.91 * x + 37251.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1533318808.289965
# [231/258]  dy_i = 84.13 * x + 38040.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1003713940.775631
# [232/258]  dy_i = 86.30 * x + 38637.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1969748995.749658
# [233/258]  dy_i = 84.41 * x + 38053.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1065068627.980519
# [234/258]  dy_i = 84.19 * x + 37464.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1305287449.844697
# [235/258]  dy_i = 86.51 * x + 37940.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1203539319.491424
# [236/258]  dy_i = 84.67 * x + 37505.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 982529973.244886
# [237/258]  dy_i = 84.96 * x + 37705.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1160703766.708412
# [238/258]  dy_i = 82.73 * x + 37807.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1125123735.719195
# [239/258]  dy_i = 82.22 * x + 38222.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1314638384.160283
# [240/258]  dy_i = 82.35 * x + 38403.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 932642886.812059
# [241/258]  dy_i = 83.27 * x + 38658.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1055648824.856006
# [242/258]  dy_i = 84.80 * x + 39012.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1548043240.155107
# [243/258]  dy_i = 81.09 * x + 38493.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1221194367.167528
# [244/258]  dy_i = 79.88 * x + 38059.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 933050426.040499
# [245/258]  dy_i = 86.57 * x + 38610.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2818622541.197960
# [246/258]  dy_i = 84.67 * x + 37868.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 986933091.263691
# [247/258]  dy_i = 80.87 * x + 37318.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1015514758.174118
# [248/258]  dy_i = 82.50 * x + 38350.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1464567155.991794
# [249/258]  dy_i = 83.56 * x + 38961.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1292284552.451048
# [250/258]  dy_i = 84.22 * x + 39474.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 969992176.091496
# [251/258]  dy_i = 82.70 * x + 39318.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1309525893.788121
# [252/258]  dy_i = 82.21 * x + 39444.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1129344502.487947
# [253/258]  dy_i = 81.84 * x + 39469.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1020063615.525281
# [254/258]  dy_i = 86.56 * x + 39392.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2813282585.322359
# [255/258]  dy_i = 86.93 * x + 39445.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 858123737.739944
# [256/258]  dy_i = 84.00 * x + 38031.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 647922978.028805
# [257/258]  dy_i = 84.07 * x + 37957.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1904541123.350907

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []
#define a batch size
batch_size = 128
# we run our loop N times
loop_N = 30*len(data)//batch_size
for i in range(loop_N):
   # We just want a sample of the dataset with batch_size size
   data_batch = data.sample(batch_size)
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()

   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d/%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,loop_N,m,b,m_calc,b_calc,loss_value))

# close/delete previous plots
plt.close('all')

# create a 1 by 2 plot grid
fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
# lot our usual output
plot_data(data_x,data_y,m,b,ax[0])

# here we also plot the calculated linear fit for comparison
line_x = np.arange(data_x.min(),data_x.max())
line_y = line_x * m_calc + b_calc
ax[0].plot(line_x,line_y,'b-',label='calculated')
# add a legend to the plot and x/y labels
ax[0].legend()
ax[0].set_xlabel('square footage')
ax[0].set_ylabel('sale price')

# plot the loss
loss_x = np.arange(0,len(loss_history))
loss_y = np.asarray(loss_history)
ax[1].plot(loss_x,loss_y, 'o-')
ax[1].set_yscale('log')
ax[1].set_xlabel('loop step')
ax[1].set_ylabel('loss')
plt.show()
# gives us time to see the plot
time.sleep(2.5)
# clears the plot when the next plot is ready to show.
ipydis.clear_output(wait=True)
# Out:
# [000/129]  dy_i = 54.86 * x + 18038.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 7724695240.483680
# [001/129]  dy_i = 72.02 * x + 25171.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1905376439.494806
# [002/129]  dy_i = 81.84 * x + 28870.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1473000396.860247
# [003/129]  dy_i = 87.00 * x + 30995.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1555951105.213706
# [004/129]  dy_i = 87.20 * x + 31345.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248782273.993048
# [005/129]  dy_i = 86.56 * x + 31470.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1278154754.153358
# [006/129]  dy_i = 87.47 * x + 31871.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1282951782.269378
# [007/129]  dy_i = 88.13 * x + 31682.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2142910587.348587
# [008/129]  dy_i = 88.22 * x + 32230.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1221155956.736394
# [009/129]  dy_i = 89.52 * x + 33007.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1064391524.061184
# [010/129]  dy_i = 91.65 * x + 32807.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1860958474.222976
# [011/129]  dy_i = 90.63 * x + 32494.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1378577867.680267
# [012/129]  dy_i = 90.76 * x + 32602.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 732220372.688089
# [013/129]  dy_i = 91.08 * x + 32877.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1427391025.055223
# [014/129]  dy_i = 89.60 * x + 32388.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1430169286.693777
# [015/129]  dy_i = 88.77 * x + 32204.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1345551669.289276
# [016/129]  dy_i = 87.10 * x + 32060.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1133161273.224595
# [017/129]  dy_i = 87.98 * x + 32826.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1089130946.006931
# [018/129]  dy_i = 87.79 * x + 32830.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153082791.588505
# [019/129]  dy_i = 89.41 * x + 33436.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1710479037.461967
# [020/129]  dy_i = 88.87 * x + 33083.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1171885120.669035
# [021/129]  dy_i = 88.39 * x + 33053.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 787652778.740762
# [022/129]  dy_i = 86.45 * x + 32707.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 966916395.876938
# [023/129]  dy_i = 88.53 * x + 32913.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2188524998.529267
# [024/129]  dy_i = 88.77 * x + 33767.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1507833469.372228
# [025/129]  dy_i = 89.65 * x + 34041.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1316761120.209666
# [026/129]  dy_i = 87.94 * x + 33803.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 884591746.722105
# [027/129]  dy_i = 88.40 * x + 34091.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1383633346.630055
# [028/129]  dy_i = 89.16 * x + 34036.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2617496464.880626
# [029/129]  dy_i = 90.90 * x + 34341.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1190720321.009822
# [030/129]  dy_i = 90.59 * x + 34181.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1097839163.740052
# [031/129]  dy_i = 87.18 * x + 33675.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1214253708.443009
# [032/129]  dy_i = 86.66 * x + 33671.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 731559271.657310
# [033/129]  dy_i = 87.38 * x + 33656.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2155348938.170938
# [034/129]  dy_i = 87.28 * x + 33808.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1575810231.899078
# [035/129]  dy_i = 88.81 * x + 33976.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2609363315.309569
# [036/129]  dy_i = 89.24 * x + 33598.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2241667550.791622
# [037/129]  dy_i = 87.23 * x + 33213.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1252213303.960819
# [038/129]  dy_i = 90.47 * x + 33665.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2087533728.655990
# [039/129]  dy_i = 89.32 * x + 33348.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405797332.595269
# [040/129]  dy_i = 89.01 * x + 33320.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1181777695.373705
# [041/129]  dy_i = 89.43 * x + 33482.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1330310773.216554
# [042/129]  dy_i = 89.86 * x + 33544.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1786509446.286709
# [043/129]  dy_i = 89.82 * x + 33541.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 820787118.564528
# [044/129]  dy_i = 90.21 * x + 33647.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1128877008.020458
# [045/129]  dy_i = 88.84 * x + 33267.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1028710290.180633
# [046/129]  dy_i = 87.78 * x + 33114.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1150084477.494400
# [047/129]  dy_i = 89.37 * x + 33148.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1037814987.596112
# [048/129]  dy_i = 88.34 * x + 33160.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 999033651.390531
# [049/129]  dy_i = 87.66 * x + 32902.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1341992722.132479
# [050/129]  dy_i = 90.28 * x + 32871.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2104238662.687453
# [051/129]  dy_i = 89.54 * x + 32700.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 954971026.181532
# [052/129]  dy_i = 89.09 * x + 32642.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1156384255.555449
# [053/129]  dy_i = 88.05 * x + 32231.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1339181555.708884
# [054/129]  dy_i = 88.33 * x + 32531.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1132549083.942444
# [055/129]  dy_i = 87.97 * x + 32516.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1250629911.692195
# [056/129]  dy_i = 88.60 * x + 33055.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1762184991.435189
# [057/129]  dy_i = 89.35 * x + 33369.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1531457450.581706
# [058/129]  dy_i = 91.13 * x + 32884.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2100337817.142209
# [059/129]  dy_i = 89.37 * x + 32838.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1723562615.856333
# [060/129]  dy_i = 89.63 * x + 32960.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1164485427.257161
# [061/129]  dy_i = 89.13 * x + 33125.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406985746.396826
# [062/129]  dy_i = 88.67 * x + 33486.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1617491407.423351
# [063/129]  dy_i = 90.59 * x + 33428.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1902088979.257562
# [064/129]  dy_i = 88.36 * x + 33450.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1241522503.474038
# [065/129]  dy_i = 89.94 * x + 33254.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2035971635.643219
# [066/129]  dy_i = 92.03 * x + 33235.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1699648642.239886
# [067/129]  dy_i = 91.44 * x + 32382.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2152454480.498067
# [068/129]  dy_i = 91.39 * x + 31694.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1869419776.807758
# [069/129]  dy_i = 89.27 * x + 31235.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1182515620.119979
# [070/129]  dy_i = 92.11 * x + 31235.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1938297606.069466
# [071/129]  dy_i = 88.94 * x + 30798.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1459022372.275848
# [072/129]  dy_i = 89.17 * x + 31133.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1016803435.016743
# [073/129]  dy_i = 92.05 * x + 31329.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2752204920.014544
# [074/129]  dy_i = 89.46 * x + 30717.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1192128675.384277
# [075/129]  dy_i = 88.49 * x + 30582.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1129817064.464300
# [076/129]  dy_i = 89.55 * x + 30683.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1826943860.739738
# [077/129]  dy_i = 90.68 * x + 31131.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 880925668.731058
# [078/129]  dy_i = 88.66 * x + 31084.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1106276706.054347
# [079/129]  dy_i = 87.82 * x + 31648.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1753287942.896223
# [080/129]  dy_i = 89.31 * x + 32046.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1221212721.565001
# [081/129]  dy_i = 91.40 * x + 32504.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1290636552.246012
# [082/129]  dy_i = 89.04 * x + 31942.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1190186516.314153
# [083/129]  dy_i = 91.07 * x + 32001.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2312959099.573246
# [084/129]  dy_i = 89.64 * x + 31986.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1378340662.264909
# [085/129]  dy_i = 90.38 * x + 32145.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 824012044.214710
# [086/129]  dy_i = 89.40 * x + 32089.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1240525019.324965
# [087/129]  dy_i = 92.07 * x + 31859.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2156959089.009856
# [088/129]  dy_i = 94.18 * x + 31764.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2437859060.122235
# [089/129]  dy_i = 92.46 * x + 31336.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 999880219.106001
# [090/129]  dy_i = 92.09 * x + 31048.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2707416553.331367
# [091/129]  dy_i = 92.23 * x + 31228.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1303709622.099458
# [092/129]  dy_i = 90.43 * x + 30643.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1167107189.943770
# [093/129]  dy_i = 88.27 * x + 30161.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1256809013.405375
# [094/129]  dy_i = 93.05 * x + 30806.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2152109585.844282
# [095/129]  dy_i = 93.65 * x + 30009.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1674566312.282144
# [096/129]  dy_i = 94.29 * x + 29503.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1886332504.147474
# [097/129]  dy_i = 91.72 * x + 28720.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1367680301.126670
# [098/129]  dy_i = 92.75 * x + 29101.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1882142684.184117
# [099/129]  dy_i = 91.27 * x + 29138.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1236687925.870076
# [100/129]  dy_i = 91.20 * x + 29560.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467672744.530206
# [101/129]  dy_i = 91.76 * x + 29827.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1086079075.182776
# [102/129]  dy_i = 91.02 * x + 29859.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1623154212.132048
# [103/129]  dy_i = 90.83 * x + 30036.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1388394348.494915
# [104/129]  dy_i = 90.62 * x + 29941.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1396441204.646357
# [105/129]  dy_i = 89.72 * x + 29684.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1441502110.080678
# [106/129]  dy_i = 89.75 * x + 29913.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1502555673.823150
# [107/129]  dy_i = 92.07 * x + 30085.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1686046832.810794
# [108/129]  dy_i = 92.45 * x + 29635.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1694469417.418684
# [109/129]  dy_i = 92.81 * x + 29678.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1216505386.580141
# [110/129]  dy_i = 93.32 * x + 29874.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1542142465.437024
# [111/129]  dy_i = 91.79 * x + 29368.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 912898487.784570
# [112/129]  dy_i = 90.74 * x + 29299.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1762739560.236798
# [113/129]  dy_i = 91.36 * x + 29673.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1289796901.843583
# [114/129]  dy_i = 92.13 * x + 29628.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2337367279.981931
# [115/129]  dy_i = 90.86 * x + 29449.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1666756584.821306
# [116/129]  dy_i = 87.80 * x + 28965.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1541823394.637130
# [117/129]  dy_i = 87.75 * x + 29701.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1513917256.181180
# [118/129]  dy_i = 90.68 * x + 30181.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1873202432.230536
# [119/129]  dy_i = 90.33 * x + 30556.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1583054038.228434
# [120/129]  dy_i = 89.99 * x + 30751.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1162476763.285257
# [121/129]  dy_i = 89.57 * x + 31012.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1108241437.481331
# [122/129]  dy_i = 90.50 * x + 31370.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1487927696.141129
# [123/129]  dy_i = 89.81 * x + 31064.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1379396972.255036
# [124/129]  dy_i = 89.77 * x + 31245.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1542722690.895248
# [125/129]  dy_i = 90.88 * x + 31170.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2609597848.297871
# [126/129]  dy_i = 88.84 * x + 30983.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1337759504.598994
# [127/129]  dy_i = 89.81 * x + 31583.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1398571572.059389
# [128/129]  dy_i = 91.92 * x + 31546.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2677923130.713025

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []
#define a batch size
batch_size = 256
# we run our loop N times
loop_N = 30*len(data)//batch_size
for i in range(loop_N):
   # We just want a sample of the dataset with batch_size size
   data_batch = data.sample(batch_size)
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()

   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d/%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,loop_N,m,b,m_calc,b_calc,loss_value))

# close/delete previous plots
plt.close('all')

# create a 1 by 2 plot grid
fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
# lot our usual output
plot_data(data_x,data_y,m,b,ax[0])

# here we also plot the calculated linear fit for comparison
line_x = np.arange(data_x.min(),data_x.max())
line_y = line_x * m_calc + b_calc
ax[0].plot(line_x,line_y,'b-',label='calculated')
# add a legend to the plot and x/y labels
ax[0].legend()
ax[0].set_xlabel('square footage')
ax[0].set_ylabel('sale price')

# plot the loss
loss_x = np.arange(0,len(loss_history))
loss_y = np.asarray(loss_history)
ax[1].plot(loss_x,loss_y, 'o-')
ax[1].set_yscale('log')
ax[1].set_xlabel('loop step')
ax[1].set_ylabel('loss')
plt.show()
# gives us time to see the plot
time.sleep(2.5)
# clears the plot when the next plot is ready to show.
ipydis.clear_output(wait=True)
# Out:
# [000/064]  dy_i = 51.58 * x + 17895.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 6557647288.146487
# [001/064]  dy_i = 72.77 * x + 25677.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2173148181.757679
# [002/064]  dy_i = 82.55 * x + 29263.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1855630733.975965
# [003/064]  dy_i = 86.20 * x + 30820.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1252520472.149125
# [004/064]  dy_i = 86.99 * x + 31499.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1220360624.912795
# [005/064]  dy_i = 89.18 * x + 31964.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1544128299.703721
# [006/064]  dy_i = 89.67 * x + 32256.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1219293345.679672
# [007/064]  dy_i = 88.98 * x + 32355.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1229431842.561343
# [008/064]  dy_i = 89.89 * x + 32545.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1590387898.531984
# [009/064]  dy_i = 88.35 * x + 32167.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1317066756.786462
# [010/064]  dy_i = 89.27 * x + 32651.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1836916632.676565
# [011/064]  dy_i = 89.21 * x + 32420.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1757773957.413884
# [012/064]  dy_i = 88.72 * x + 32465.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1080926559.752847
# [013/064]  dy_i = 89.59 * x + 32761.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1565943957.264487
# [014/064]  dy_i = 88.59 * x + 32413.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1857181323.415140
# [015/064]  dy_i = 88.62 * x + 32147.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1376420650.838113
# [016/064]  dy_i = 88.22 * x + 32293.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153137509.239680
# [017/064]  dy_i = 88.47 * x + 32441.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1678732909.418145
# [018/064]  dy_i = 88.61 * x + 32707.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1200499590.066543
# [019/064]  dy_i = 88.75 * x + 32712.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1127316284.298221
# [020/064]  dy_i = 89.88 * x + 32663.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1543416488.712434
# [021/064]  dy_i = 90.19 * x + 32615.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1840274016.477598
# [022/064]  dy_i = 89.85 * x + 32672.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1524366399.667424
# [023/064]  dy_i = 89.34 * x + 32892.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1102227427.017723
# [024/064]  dy_i = 90.48 * x + 33012.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1869546217.181247
# [025/064]  dy_i = 91.16 * x + 32960.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1639285012.926648
# [026/064]  dy_i = 89.54 * x + 32414.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1954728613.308248
# [027/064]  dy_i = 90.49 * x + 32636.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1115106514.754560
# [028/064]  dy_i = 89.25 * x + 32192.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1609211011.090405
# [029/064]  dy_i = 89.64 * x + 32166.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1612890023.028839
# [030/064]  dy_i = 89.87 * x + 32172.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1737088918.688074
# [031/064]  dy_i = 88.26 * x + 31928.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1215318203.709149
# [032/064]  dy_i = 89.63 * x + 32343.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1887440780.263372
# [033/064]  dy_i = 91.19 * x + 32514.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1870182298.989509
# [034/064]  dy_i = 90.74 * x + 32216.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1798030060.985599
# [035/064]  dy_i = 90.20 * x + 32228.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1416020444.851597
# [036/064]  dy_i = 90.28 * x + 32104.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1714425320.689447
# [037/064]  dy_i = 90.88 * x + 31990.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1562700001.000812
# [038/064]  dy_i = 91.03 * x + 32018.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1867986774.694601
# [039/064]  dy_i = 91.41 * x + 31809.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1670403641.748215
# [040/064]  dy_i = 90.24 * x + 31524.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1127784119.455959
# [041/064]  dy_i = 88.24 * x + 31363.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1214354401.014051
# [042/064]  dy_i = 88.91 * x + 31483.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1844843886.541298
# [043/064]  dy_i = 89.81 * x + 31516.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1702405270.407705
# [044/064]  dy_i = 90.79 * x + 31636.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1674524401.509252
# [045/064]  dy_i = 90.42 * x + 31561.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1654407685.230358
# [046/064]  dy_i = 90.22 * x + 31890.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1241139355.231776
# [047/064]  dy_i = 90.38 * x + 31920.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1851809369.005375
# [048/064]  dy_i = 90.04 * x + 31990.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1239272265.584866
# [049/064]  dy_i = 88.62 * x + 31927.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1339034220.874899
# [050/064]  dy_i = 88.75 * x + 32280.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1213144179.432489
# [051/064]  dy_i = 90.13 * x + 32466.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626621442.328284
# [052/064]  dy_i = 90.08 * x + 32201.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1590421668.014686
# [053/064]  dy_i = 90.04 * x + 32091.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1817762698.705026
# [054/064]  dy_i = 89.71 * x + 31994.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1104368981.927185
# [055/064]  dy_i = 87.79 * x + 31781.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1158164489.990674
# [056/064]  dy_i = 88.20 * x + 32207.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1431091216.571383
# [057/064]  dy_i = 89.90 * x + 32346.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1616837792.151885
# [058/064]  dy_i = 90.01 * x + 32584.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1240813934.210539
# [059/064]  dy_i = 88.99 * x + 32672.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1561895024.137842
# [060/064]  dy_i = 88.78 * x + 33061.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1282072183.649143
# [061/064]  dy_i = 88.43 * x + 33081.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1314326224.011889
# [062/064]  dy_i = 88.27 * x + 33129.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1229209295.515723
# [063/064]  dy_i = 89.83 * x + 33248.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1886930132.856542

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []
#define a batch size
batch_size = 512
# we run our loop N times
loop_N = 30*len(data)//batch_size
for i in range(loop_N):
   # We just want a sample of the dataset with batch_size size
   data_batch = data.sample(batch_size)
   # convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
   data_x = data_batch['GrLivArea'].to_numpy()
   data_y = data_batch['SalePrice'].to_numpy()

   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d/%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,loop_N,m,b,m_calc,b_calc,loss_value))

# close/delete previous plots
plt.close('all')

# create a 1 by 2 plot grid
fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
# lot our usual output
plot_data(data_x,data_y,m,b,ax[0])

# here we also plot the calculated linear fit for comparison
line_x = np.arange(data_x.min(),data_x.max())
line_y = line_x * m_calc + b_calc
ax[0].plot(line_x,line_y,'b-',label='calculated')
# add a legend to the plot and x/y labels
ax[0].legend()
ax[0].set_xlabel('square footage')
ax[0].set_ylabel('sale price')

# plot the loss
loss_x = np.arange(0,len(loss_history))
loss_y = np.asarray(loss_history)
ax[1].plot(loss_x,loss_y, 'o-')
ax[1].set_yscale('log')
ax[1].set_xlabel('loop step')
ax[1].set_ylabel('loss')
plt.show()
# gives us time to see the plot
time.sleep(2.5)
# clears the plot when the next plot is ready to show.
ipydis.clear_output(wait=True)
# Out:
# [000/032]  dy_i = 52.29 * x + 17790.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 6353005268.938831
# [001/032]  dy_i = 73.46 * x + 25134.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2342113393.946464
# [002/032]  dy_i = 82.49 * x + 28470.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1700550645.396130
# [003/032]  dy_i = 86.40 * x + 30014.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1529595740.265877
# [004/032]  dy_i = 88.28 * x + 30750.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1510103673.882400
# [005/032]  dy_i = 89.07 * x + 31138.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1472596854.206586
# [006/032]  dy_i = 89.70 * x + 31363.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1508446388.383490
# [007/032]  dy_i = 89.84 * x + 31467.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1517842071.283482
# [008/032]  dy_i = 89.93 * x + 31602.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1495793308.495612
# [009/032]  dy_i = 89.32 * x + 31663.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1292917884.565919
# [010/032]  dy_i = 89.34 * x + 31754.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1519020782.371294
# [011/032]  dy_i = 89.77 * x + 31911.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1497936367.034289
# [012/032]  dy_i = 89.92 * x + 31979.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1514531815.349033
# [013/032]  dy_i = 89.47 * x + 32049.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1266134915.915179
# [014/032]  dy_i = 89.41 * x + 32147.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1466284274.965179
# [015/032]  dy_i = 89.10 * x + 32178.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1462758468.892695
# [016/032]  dy_i = 89.20 * x + 32285.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1480979449.357211
# [017/032]  dy_i = 89.13 * x + 32343.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1535795885.217975
# [018/032]  dy_i = 88.38 * x + 32363.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1303853353.749169
# [019/032]  dy_i = 88.82 * x + 32550.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1536332662.219928
# [020/032]  dy_i = 89.22 * x + 32658.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1463936715.378654
# [021/032]  dy_i = 89.20 * x + 32699.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1526896240.473682
# [022/032]  dy_i = 89.32 * x + 32719.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1481998228.846095
# [023/032]  dy_i = 88.78 * x + 32626.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1522912456.594511
# [024/032]  dy_i = 89.01 * x + 32783.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1487358667.422752
# [025/032]  dy_i = 88.87 * x + 32801.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1541092795.396187
# [026/032]  dy_i = 89.00 * x + 32886.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1475049977.743181
# [027/032]  dy_i = 88.66 * x + 32874.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1489070029.983647
# [028/032]  dy_i = 88.06 * x + 32993.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1226825496.767974
# [029/032]  dy_i = 88.55 * x + 33182.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1536541125.054965
# [030/032]  dy_i = 87.86 * x + 33219.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1241262364.884771
# [031/032]  dy_i = 88.46 * x + 33383.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1495804582.143407
